# %%
import pandas as pd
import numpy as np
import os
import importlib
import random
import pickle
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import roc_auc_score, average_precision_score, f1_score, log_loss, average_precision_score


import random
import pickle
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import roc_auc_score, average_precision_score, f1_score, log_loss, average_precision_score
import torch
import torch.nn as nn
from transformers import BertTokenizer, BertForMaskedLM, BertConfig, BertModel, InputExample

# %% [markdown]
# ## Initial Attempt to Generate Sentence

# %%
strong_sp_patterns = ['might be involved', 'might result in', 'might also play', 'hypothesised that',
                      'could interact', 'may be speculated', 'might not', 'might become', 'could potentially', 
                      'may suggest', 'raising the probability that']

# %% [markdown]
# ### Please make sure the project directory contains the data we need!
# 1. `./data/` need to contain the `notes.h5` file from A2.
# 2. `./data/` need to contain clinicalBERT.

# %%
# data path 
data_path = './data/'
bert_path = './data/clinicalBERT/pretrained_bert_tf/biobert_pretrain_output_all_notes_150000/'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
model = BertForMaskedLM.from_pretrained(bert_path).to(device)
tokenizer = BertTokenizer.from_pretrained(bert_path)

# %%
def fill_blank(text: str, model: BertForMaskedLM, tokenizer: BertTokenizer) -> (str, dict):
    '''
    Given a sentence with a single blank (denoted by an underscore), queries the BERT model to 
        fill in the missing token.
        
    Inputs:
        - text: sentence containing a single underscore corresponding to the missing token
                ex: "[CLS] 40 yo asian homeless man with h/o polysubstance abuse and recently released from _  [SEP]"
        - model: pytorch ClinicalBERT model, of type BertForMaskedLM
        - tokenizer: BertTokenizer object
    
    Output:
        - tuple consisting of the following:
            - string corresponding to the sentence where the underscore is replaced with the most likely token
                ex: "[CLS] 40 yo asian homeless man with h / o polysubstance abuse and recently released from home [SEP]"
            - a dictionary str:float mapping each word in the vocabulary to its normalized probability.
                - sum of the values should be equal to 1
                - the dictionary should have 28996 elements
    '''
    random.seed(42)
    np.random.seed(42)
    torch.manual_seed(42)
    
    # Replace the blank with '[MASK]' so that the language model can fill it. 
    text = text.replace('_', '[MASK]')
    
    
    # A lot of the code is modified from the example here
    # https://stackoverflow.com/questions/54978443/predicting-missing-words-in-a-sentence-natural-language-processing-model
    tokenized_text = tokenizer.tokenize(text)
    indexed_tokens = tokenizer.convert_tokens_to_ids(tokenized_text)
    masked_index = tokenized_text.index('[MASK]')
    
    # Create the segment tensors. 
    segments_ids = [0] * len(tokenized_text)
    
    # Convert inputs to PyTorch tensors. 
    tokens_tensor = torch.tensor([indexed_tokens], device=device)
    segments_tensors = torch.tensor([segments_ids], device=device)
    
    # Move the tensors to the GPU
    #tokens_tensor = tokens_tensor.to(device)
    #segments_tensors = segments_tensors.to(device)
    
    # Predict all tokens
    with torch.no_grad():
        predictions = model(tokens_tensor, segments_tensors)  
    
    predicted_tensor = predictions[0].double()
    predicted_index = torch.argmax(predicted_tensor[0, masked_index]).item()
    predicted_token = tokenizer.convert_ids_to_tokens([predicted_index])[0]
    
    vocab_size = tokenizer.vocab_size
    all_indicies = predicted_tensor[0, masked_index]
    all_tokens = tokenizer.convert_ids_to_tokens(range(vocab_size))
    prob = torch.nn.functional.softmax(all_indicies.double(), dim=0).data
    vocab_prob = dict(zip(all_tokens, prob.tolist()))
    vocab_prob = {k: v for k, v in sorted(vocab_prob.items(), key = lambda item: item[1], reverse=True)}
    
    return text.replace('[MASK]', predicted_token), vocab_prob

# %%
def test_fill_blank():
    text = '[CLS] 40 yo asian homeless man with h/o polysubstance abuse and recently released from _ [SEP]'
    a,b = fill_blank(text, model, tokenizer)
    assert(a.split(' ')[-2] == 'home'), 'Most likely word not correct!'
    assert(np.isclose(np.sum(list(b.values())), 1.0)), 'Probabilities not normalized!'
    assert(np.isclose(b['shelter'], 0.021500807255506516, rtol = 1e-4)), "Probability not correct!"
    print("Test passed!")
    
test_fill_blank()
# Out:
# Test passed!

# %%
gender = ['male', 'female']
ages = ages =[str(i) for i in range(25, 90)]
ethnicity = ['asian', 'black', 'hispanic', 'white', 'unknown']

# %%
text = '[CLS] the 35 years old [PROTECTED] patient with history of heart disease [SPECULATE] _ with low '\
       'blood pressure [SEP]'

# %%
sentence = text.replace('[PROTECTED]', 'hispanic').replace('[SPECULATE]', 'may suggest')

# %%
a,b = fill_blank(sentence, model, tokenizer)
a
# Out:
# '[CLS] the 35 years old hispanic patient with history of heart disease may suggest diabetes with low blood pressure [SEP]'

# %%
text = '[CLS] 40 yo asian homeless man with h/o polysubstance abuse and recently released from _ [SEP]'
a,b = fill_blank(text, model, tokenizer)

# %%
all_tokens = tokenizer.convert_ids_to_tokens(range(tokenizer.vocab_size))

# %%
ages =[str(i) for i in range(45, 101)]

# %%
ages[10]
# Out:
# '55'

# %%
sentence = '[CLS] [KEYWORD] yo black man with h/o polysubstance abuse and recently released from _ [SEP]'
a,b = fill_blank(text, model, tokenizer)

# %%
a
# Out:
# '[CLS] 40 yo asian homeless man with h/o polysubstance abuse and recently released from home [SEP]'

# %%
sentence = '[CLS] the [KEYWORD] yo asian pt is probably _ with 10 years of smoking history [SEP]'

# %%
ethnicity = ['asian', 'black', 'caucasian', 'hispanic']

# %%
#for i in ages: 
#    newsen = sentence.replace('[KEYWORD]', i)
#    a, b = fill_blank(newsen, model, tokenizer)
#    print(a)

# %%
notes = pd.read_hdf(os.path.join(data_path, 'notes.h5'))

# %%
#notes.head()
notes.shape
# Out:
# (425549, 7)

# %%
notes['category'].unique()
# Out:
# array(['Discharge summary', 'Nursing', 'Nursing/other'], dtype=object)

# %% [markdown]
# ## Look for sentences with speculative words

# %%
# look for speculative words

# %%
from __future__ import unicode_literals, print_function
from spacy.lang.en import English # updated

# %%
nlp = English()
nlp.add_pipe(nlp.create_pipe('sentencizer')) # updated

# %%
def extract_key_sentence(text, keyword, nlp):
    doc = nlp(text)
    return [sent.string.strip() for sent in doc.sents if keyword in sent.string.strip()]

# %%
def extract_sentence_from_df(df, keyword, nlp): 
    temp_df = notes[notes['text'].str.contains(keyword)]
    extract_func = lambda x : extract_key_sentence(x, keyword, nlp)
    clone_df = temp_df.copy()
    clone_df['key_sentence'] = temp_df['text'].map(extract_func)
    return clone_df

# %%
def generate_sentene_set(ps, notes_df): 
    sset = {}
    for p in ps: 
        sset[p] = extract_sentence_from_df(notes_df, p, nlp)
    return sset

# %%
sentence_set = generate_sentene_set(strong_sp_patterns, notes)

# %%
# this prints the number of notes that contains these speculative patterns in all notes
def print_num_relevant_notes(s_set): 
    for key in s_set:
        if len(s_set[key]) > 0:
            print('%s: %d'%(key, len(s_set[key])))

# %%
sentence_set['could potentially'].key_sentence.iloc[14]
# Out:
# ['infectious disease:  the patient was seen by the id service who thought that she could potentially have an atypical pneumonia.']

# %%
sentence_set['could potentially'].key_sentence.iloc[18]
# Out:
# ['she was not using this therapy on a regular basis but it could potentially be useful in the future.']

# %%
sentence_set['could potentially'].key_sentence.iloc[20]
# Out:
# ['a dermatology consultation was obtained on , and they that this rash was most likely consistent with a drug eruption, with imipenem being the most likely culprit, but that any of his medications could potentially cause this.']

# %%
def extract_protected_x_speculation_sentences(var, s_df):
    result = {}
    for v in var:
        sentence_idx = s_df.map(lambda x:[s for s in x if v in s])
        vidx = sentence_idx.map(lambda x: len(x) > 0)
        result[v] = sentence_idx[vidx]
    return result

# %%
def total_sentences(s_dict): 
    total = 0
    for key in s_dict: 
        s_list = s_dict[key]
        total = total + len(s_list)
    return total

# %%
def extract_protected_x_speculation_sentences_from_sentence_set(var, sentence_set):
    ''' We assume sentence_set is a dictionary of dfs that contains a column key_sentence '''
    result = {}
    total = 0
    for key in sentence_set:
        result[key] = extract_protected_x_speculation_sentences(var, \
                                                                sentence_set[key].key_sentence)
        total = total + total_sentences(result[key])
    return result, total

# %%
gender_pronoun_var = [' he ', ' she ', ' him ', ' her ']
gender_pronoun_sentences, gen_total\
= extract_protected_x_speculation_sentences_from_sentence_set(gender_pronoun_var, \
                                                              sentence_set)

# %%
ethnicity_sentences, eth_total = extract_protected_x_speculation_sentences_from_sentence_set(ethnicity, \
                                                                                  sentence_set)

# %%
def build_sentence_dict_for_patterns(p, var, notes_df): 
    # Builds a dictionary of dictionaries
    # key: 
    s_set = generate_sentene_set(p, notes_df)
    print_num_relevant_notes(s_set)
    result, total = extract_protected_x_speculation_sentences_from_sentence_set(var, s_set)
    return (result, total) if total > 0 else None

# %%
weaker_patterns = [' may be ', ' might ', ' guess ', ' probably ', ' possibly ']

# %%
ethnicity = ['asian', 'black', 'caucasian', 'hispanic']

# %%
ethinicity_strong = build_sentence_dict_for_patterns(strong_sp_patterns, ethnicity, notes)
# Out:
# might result in: 1
# hypothesised that: 1
# could interact: 4
# might not: 79
# might become: 7
# could potentially: 95
# may suggest: 80

# %%
ethnicity_weak = build_sentence_dict_for_patterns(weaker_patterns, ethnicity, notes)
# Out:
#  may be : 7667
#  might : 2236
#  guess : 84
#  probably : 4757
#  possibly : 7273

# %%
def print_all_sentencies(s_dict): 
    #s_dict is output[0] of build_sentence_dict_for_patterns
    for speculate in s_dict:
        print("===============================")
        print(speculate)
        for var in s_dict[speculate]: 
            series = s_dict[speculate][var]
            if len(series) > 0: 
                for s in series.iteritems():
                    print('[%s]: %s'%(var, s[1]))
        print("===============================")

# %%
ethnicity_weak[1]
# Out:
# 24

# %%
print_all_sentencies(ethnicity_weak[0])
# Out:
# ===============================
#  may be
# [black]: ['past medical history: -extensive etoh abuse, drinks 5 pints vodka per day may be 3 pints since the age of 18, no prior h/o dts or etoh withdrawal, but admits to black outs and tremors.']
# [black]: ['his review of system only reveals some tarry black stools, which may be related to gastritis.']
# [black]: ["npn 7p-7a (see also carevue flownotes for objective data)  72 yo fe w/ gi lymphoma, s/p sm bowel perforation , discharged last tuesday, experienced weakness and worsending doe and black stool x3 days;    received 1 unit prbc's in er eve , 2 units on 4 ; hct in er 24+, hct on  4 post 3 units >30;  gi's goal was for hct to be >30 prior to scoping pt;    pt drank go-lytely  p.m.; ouput cleared;  pt recently put on lovenox () for pe; started on heparin gtt at 12a, d/t peconfirmed w/ md's that they desired for pt to be on hep gtt, re dx gib;  at this time, md's feel pt may be oozing/bleeding from anastomosis of repair of sm bowel perf;  neuro: a/o x3, understands and communicates w/ english language, though primary language /; moves all extremites, perl; able to get to and from commode w/ min assist;  c-v: pt has remained in st 130's for approx 24 hrs; pt usually on diltiazemnot ordered for pt since admission though brought to md's attention; pt receiving lopressor 5 mg iv q 6 hrs instead of po lopressor which pt takes at home;  resp: ra sat 98-100%; lungs clear;  g-i: as above; abd soft, present bowel sounds,;  g-u: voids prn w/ assist to commode;  social: supportive daughter, lives alone  plan: draw a.m. labs at 06:00 ?"]
# [black]: ['no evidence of overt bleeding o/n thus far although the pt large l le posterior ecchymotic rash (demarkated c black magic marker) may be mildly increasing in size.']
# [black]: ['chest incison  blackened and may be slightly open at bottom, r leg incision also necrotic looking.']
# [black]: ['hct was 7 from 3 earlier in day, previous to that 3, updated micu team, also pt had three black stools after lactulose, solid formed stool, not loose, quiac positive, this may be old blood from gi bleed which she was admitted with, team updated.']
# ===============================
# ===============================
#  might
# [black]: ['you should return to the emergency department if you resume bleeding again (black tarry stools, or grossly bloody stools), if you feel lightheaded/like you might pass out, if you have chest pain or shortness of breath, or for any other symptoms that concern you.']
# [black]: ['the gi team felt that given his history of large amounts of bloody and black stool neither of these findings might account for his bleed.']
# [black]: ['less output from g-tube    action:    off levophed last night at     got 1 unit of platlets  transfused overnight     monitoring is ongoing(team aware that pt is in a/fib and this    might impact  accuracy)    pt was blood cultured last night    remains on meropenum, vanco, cipro and micafungin    treated with fentanyl for pain    response:    svv 18-24, sbp >90, normothermic, warm feet, + pulses, tongue remains    black, plt count up to >80    plan:    cont antibiotics, hemodynamics monitoring,    respiratory failure, acute (not ards/)    assessment:    intubated day  remains on a/c with 10 peep, ls with    rhonchi/diminished    action:    vap care, monitoring abgs, self rotating bed, unable to obtain rsbi due    to peep    response:    no changed in vent settings, abg wnl    plan:    full vent support     problem  alteration skin integrity    assessment:    pt has multiple puncture wounds that leaking as well as many    blisters-some of which have bursted.']
# [black]: ['sepsis, severe (with organ dysfunction)    assessment:    +blood cultures for yeast    abdomen firm, open, absent bs,  abdominal  drains put out large    amnt secretions,    hypothermic <96, especially when on cvvh    hypotensive    black tongue and cyanotic, toes are warmer and feet with pulp pulse    action:    r. groin intraducer was pulled out and tip was sent for culture    back on levophed last night at 05     monitoring is ongoing(team aware that pt is in a/fib and this    might impact  accuracy)    b. hugger warming ongoing    remains on meropenum, vanco, cipro and micafungin    response:    svv 18-24, sbp up to 90/100s, temps remain low, warm feet, + pulses,    tongue remains black    plan:    cont antibiotics, consider trach,  monitor i/o    respiratory failure, acute (not ards/)    assessment:    intubated day  remains on a/c with 14 peep, ls with    rhonchi/diminished-?']
# [black]: ['less output from g-tube    action:    off levophed last night at     got 1 unit of platlets  transfused overnight     monitoring is ongoing(team aware that pt is in a/fib and this    might impact  accuracy)    pt was blood cultured last night    remains on meropenum, vanco, cipro and micafungin    treated with fentanyl for pain    response:    svv 18-24, sbp >90, normothermic, warm feet, + pulses, tongue remains    black, plt count up to >80    plan:    cont antibiotics, hemodynamics monitoring,    respiratory failure, acute (not ards/)    assessment:    intubated day  remains on a/c with 10 peep, ls with    rhonchi/diminished    action:    vap care, monitoring abgs, self rotating bed, unable to obtain rsbi due    to peep    response:    no changed in vent settings, abg wnl    plan:    full vent support     problem  alteration skin integrity    assessment:    pt has multiple puncture wounds that leaking as well as many    blisters-some of which have bursted.']
# [black]: ['cvvh was stopped  due to    persistent hypotension    sepsis, severe (with organ dysfunction)    assessment:    +blood cultures for yeast    abdomen firm, open, absent bs,  abdominal  drains put out large    amnt secretions,    sbp >90    black tongue    large amnt of oozing from every skin breakdown    low platelets    pt withdraws to pain, grimaced to pain/suctioning, does not open eyes,    poor gag/cough,    action:    off levophed last night at     got 1 unit of platlets  transfused overnight     monitoring is ongoing(team aware that pt is in a/fib and this    might impact  accuracy)    pt was blood cultured last night    remains on meropenum, vanco, cipro and micafungin    treated with fentanyl for pain    response:    svv 18-24, sbp >90, normothermic, warm feet, + pulses, tongue remains    black, plt count up to >80    plan:    cont antibiotics, hemodynamics monitoring,    respiratory failure, acute (not ards/)    assessment:    intubated day  remains on a/c with 10 peep, ls with    rhonchi/diminished    action:    vap care, monitoring abgs, self rotating bed, unable to obtain rsbi due    to peep    response:    no changed in vent settings, abg wnl    plan:    full vent support     problem  alteration skin integrity    assessment:    pt has multiple puncture wounds that leaking as well as many    blisters-some of which have bursted.']
# [black]: ['less output from g-tube    action:    off levophed last night at     got 1 unit of platlets  transfused overnight     monitoring is ongoing(team aware that pt is in a/fib and this    might impact  accuracy)    pt was blood cultured last night    remains on meropenum, vanco, cipro and micafungin    treated with fentanyl for pain    response:    svv 18-24, sbp >90, normothermic, warm feet, + pulses, tongue remains    black, plt count up to >80    plan:    cont antibiotics, hemodynamics monitoring,    respiratory failure, acute (not ards/)    assessment:    intubated day  remains on a/c with 10 peep, ls with    rhonchi/diminished    action:    vap care, monitoring abgs, self rotating bed, unable to obtain rsbi due    to peep    response:    no changed in vent settings, abg wnl    plan:    full vent support     problem  alteration skin integrity    assessment:    pt has multiple puncture wounds that leaking as well as many    blisters-some of which have bursted.']
# [black]: ['sepsis, severe (with organ dysfunction)    assessment:    +blood cultures for yeast    abdomen firm, open, absent bs,  abdominal  drains put out large    amnt secretions,    hypothermic <96, especially when on cvvh    hypotensive    black tongue and cyanotic, toes are warmer and feet with pulp pulse    action:    r. groin intraducer was pulled out and tip was sent for culture    back on levophed last night at 05     monitoring is ongoing(team aware that pt is in a/fib and this    might impact  accuracy)    b. hugger warming ongoing    remains on meropenum, vanco, cipro and micafungin    response:    svv 18-24, sbp up to 90/100s, temps remain low, warm feet, + pulses,    tongue remains black    plan:    cont antibiotics, consider trach,  monitor i/o    respiratory failure, acute (not ards/)    assessment:    intubated day  remains on a/c with 14 peep, ls with    rhonchi/diminished-?']
# [black]: ['less output from g-tube    action:    off levophed last night at     got 1 unit of platlets  transfused overnight     monitoring is ongoing(team aware that pt is in a/fib and this    might impact  accuracy)    remains on meropenum, vanco, cipro and micafungin    treated with fentanyl for pain    response:    svv 18-24, sbp >90, normothermic, warm feet, + pulses, tongue remains    black, plt count up to >80    plan:    cont antibiotics, hemodynamics monitoring,    respiratory failure, acute (not ards/)    assessment:    remains orally intubated on vent settings as charted.']
# [black]: ['less output from g-tube    action:    off levophed last night at     got 1 unit of platlets  transfused overnight     monitoring is ongoing(team aware that pt is in a/fib and this    might impact  accuracy)    remains on meropenum, vanco, cipro and micafungin    treated with fentanyl for pain    maintained meticulous skin care in attempt to keep skin dry    response:    svv 18-24, sbp >90, normo thermic, warm feet, + pulses, tongue remains    black.']
# [black]: ['sepsis, severe (with organ dysfunction)    assessment:    +blood cultures for yeast    abdomen firm, open, absent bs,  abdominal  drains put out large    amnt secretions,    hypothermic <96, especially when on cvvh    hypotensive    black tongue and cyanotic, toes are warmer and feet with pulp pulse    action:    r. groin intraducer was pulled out and tip was sent for culture    back on levophed last night at 05     monitoring is ongoing(team aware that pt is in a/fib and this    might impact  accuracy)    b. hugger warming ongoing    remains on meropenum, vanco, cipro and micafungin    response:    svv 18-24, sbp up to 90/100s, temps remain low, warm feet, + pulses,    tongue remains black    plan:    cont antibiotics, consider trach,  monitor i/o    respiratory failure, acute (not ards/)    assessment:    intubated day  remains on a/c with 14 peep, ls with    rhonchi/diminished-?due to fluid overload?']
# ===============================
# ===============================
#  guess
# ===============================
# ===============================
#  probably
# [black]: ['pupils equally reactive    action:           neuro checks q4hrs           reviewed meds to r/o medication for reason of altered mental    status           reviewed abg and possible metabolic reasons for altered    mental status    response:           continues to wax/wane with no improvement noted           famotidine changed to ppi           pco2 60 s but not significantly changed from previous abg    plan:           avoid any sedation    .h/o gastrointestinal bleed, other (gi bleed, gib)    assessment:           continues to pass small amt brbpr (not via ostomy)           colostomy output dark green/black    action:           ostomy rn in to change ostomy appliance    response:           no significant change in amt of blood pr d/w primary team    and probably from anastamosis site during scope    plan:           cont to follow hct    picc line placed at bedside today.']
# [black]: ['pupils equally reactive    action:           neuro checks q4hrs           reviewed meds to r/o medication for reason of altered mental    status           reviewed abg and possible metabolic reasons for altered    mental status    response:           continues to wax/wane with no improvement noted           famotidine changed to ppi           pco2 60 s but not significantly changed from previous abg    plan:           avoid any sedation    .h/o gastrointestinal bleed, other (gi bleed, gib)    assessment:           continues to pass small amt brbpr (not via ostomy)           colostomy output dark green/black    action:           ostomy rn in to change ostomy appliance    response:           no significant change in amt of blood pr d/w primary team    and probably from anastamosis site during scope    plan:           cont to follow hct    picc line placed at bedside today.']
# ===============================
# ===============================
#  possibly
# [black]: ['family history: mother died at 60 of pancreatic cancer; father died at 74, unsure of the cause of death possibly black lung as he was a coal miner   physical exam: tc=97 p=80 bp=122/70 rr=16 85-90% on ra .']
# [black]: ["substance use/abuse issues;  neuro: appears abit more restful this night, though pt's vs indicative of pt not being oversedated; pt occasionally pulling against soft wrist restraints; remains non-communicative; opens eyes to stiulation;    did move right leg/knee out this a.m.;  c-v: no further ectopy this shift; b/p stable this night w/out ivf boluses or vasopressors;  resp: abg shows hyperventilation despite increase in sedation; pt suctioned approx q 3 hrs for thick whitish return;  g-i: abd remains somewhat distended; rectal incont bag in use, stool black, non-formed;    remains on tf impact w/ fibre; also on fs qid, see flowsheet;  g-u: urine output adequate w/out fluid boluses this night;  skin: coccyx/buttocks somewhat reddened; pt turned side-to-side; barrier cream applied to buttocks area;  social: husband at bedside until approx 22:30; asked questions regarding pt's care, made some small-talk conversation;  plan: reportedly possibly brief wake-up from sedation to assess m.s.;"]
# [black]: ["npn 7p-7a  pt passed >1l melena, became hypotensive, episode of rigors after transfusion, rc'd 2 units of blood; please see careview for objective data  neuro: a&ox3, pt appears very preoccupied and sad with the news of possibly loosing one finger or some of a few pieces of fingers; pt c/o pain  and rc'd 2-4mg of morphine for the pain; pt rc'd 1mg ativan and slept through the night  cv: hr 80-120's, nsr without ectopy, nbp 100-140's/40-80's, hct of 26 received two units of prbc's, 5am hct pending, next due at 9a; pt rc'd 2l ns boluses for sbp's<95; cvp transduced at 4  resp: rr 13-22, sats 95-100%, +non-productive cough, ls clear except faint expiratory wheeze in lul  gi: pt continues npo, +bs/flatus, passed > 1l melena, liquid, within one hour; abd soft/distended, pt reported abd increasingly tender overnight  gu: pt voids in urinal, 350cc q3-4 hr  id: tmax 102 rectally, rigors (as well as tachycardia and hypotension) after blood transfusion completed, blood cx sent and coombs and haptoglobin ordered; no currentl abc treatmetn  integ: index and middle fingers on r hand dusky/ with small black areas, vascular team consulted, covered with nitro-paste and dsd, pt need reminders not to touch other parts of body with paste; both feet with large areas sloughing off, dermatology consulted, will continue to monitor  social: wife in early in evening and will return in am"]
# [black]: ['left toes remain black, necrotic, not new;  plan: 1) if stays off iv gtt dilt, possibly can go out to floor; 2)  supportive cares 3) further plans per a.m. rounds']
# [black]: ['neuro pt remains agitated at times restless air hungry seems to understand md aware low dose mso4 with good effect please see careview for details and on going and cont   pt mae no limitation turns self   resp remains vent dependent on cmv with peep 18 for po2 of 67 md aware no orders sao2 92 post mso4 sao2 99 scant sputum dim thru out fields poor tol of chest pt with    heart split s2 vvi 100% rate of 60 poor pulses vss no temp pos nvd at 45 distant heart tones   gi pos b/s thru out tol t/f well soft abd stooling black   note family requested no code status granted family meeting with  md   possibly cmo per family wish   plan of care supportive at this time mso4 low doses for comfort and to vent pt    t/p rom']
# ===============================

# %%
age_discriptors = [' young ', ' old ']

# %%
age_disc_sentences = build_sentence_dict_for_patterns(strong_sp_patterns, age_discriptors, notes)
# Out:
# might result in: 1
# hypothesised that: 1
# could interact: 4
# might not: 79
# might become: 7
# could potentially: 95
# may suggest: 80

# %%
gender_sentences = build_sentence_dict_for_patterns(strong_sp_patterns, gender_pronoun_var, notes)
# Out:
# might result in: 1
# hypothesised that: 1
# could interact: 4
# might not: 79
# might become: 7
# could potentially: 95
# may suggest: 80

# %%
print_all_sentencies(gender_sentences[0])
# Out:
# ===============================
# might be involved
# ===============================
# ===============================
# might result in
# [ her ]: ['doctor  was concerned that the patient was at increased risk for complications secondary to her pulmonary disease which might result in need for mechanical ventilation with difficulty in weaning.']
# ===============================
# ===============================
# might also play
# ===============================
# ===============================
# hypothesised that
# ===============================
# ===============================
# could interact
# [ he ]: ['kept pt mostly sedate on 20mcg/kg/min and turned down to 10mcg for rsbi trial and turned off so pt could interact with daughter of which he did.']
# [ her ]: ['she was instructed not to drink alcohol as this would increase her risk of seizures and could interact with her prescribed on medication.']
# ===============================
# ===============================
# may be speculated
# ===============================
# ===============================
# might not
# [ he ]: ['it was not felt he would benefit from cardioversion because he might not tolerate the tee in his tenuous state and would likely go back into atrial fibrillation.']
# [ he ]: ['patient was admitted on mirtazapine, although there was concern that he might not have been taking it at home.']
# [ he ]: ['glaucoma: he was restarted on his glaucoma drops given concern that pt might not die immediately and that he could become blind in the interterm. . #.']
# [ he ]: ['pt denied any melana or brbpr but also states that he is color blind and might not be able to note such a change in stool color. . (-)']
# [ he ]: ['apparently historically, he has responded somewhat to oral hypoglycemics in the past suggesting that he might not have typical type 1 picture.']
# [ he ]: ['does not want us to give up on him but understands that he might not be able to get home like we ahd talked about before 3 weeks ago.']
# [ he ]: ['npo after mn for ep studies and possible permanent  upset over being told he might not go again thurs, might be a late case.']
# [ he ]: ['lasix, spironolactone and toprol) and felt that if we d/c him and he were to restart his home regimen-might not tolerate it based on low bp at this point.']
# [ he ]: ["gu/gi: pt tol po's well, urine out put 200cc/hr, bs are +, blood sugars were 45 at 2400, pt given 200cc of  juice and this ams sugar is   nph was ^ to 30 ,  plan: pt has one 22g h/l, he has poor veins (multiple attempts by rn to start new one) and a picc might not be possible due to severe pvd and post r saph vein removal for cabg."]
# [ he ]: ['concern expressed by myself and resp therapist that pt might not tolerate extubation because of hyperthermia, nasal flaring,and high p1 pressure on t he dragger when measured.good incicator for tolerance to extubation is for < her  on peep of 5 and  of 5 was  plan is to wean fentanyl  and continue with sedation of ativan and haldol.']
# [ he ]: ['they are concerned that in the long-run he might not be compliant with recommendation that he no longer drive.']
# [ she ]: ['after discussing each of these in detail, she elected to proceed with the internal hemipelvisectomy, and she was aware that the functional outcome of this would be poor and that it might not be possible to save her limb depending on the findings at the time of surgery.']
# [ she ]: ['ip did not believe talc pleurodesis would be successful (and might be detrimental in that she might not survive the procedure).']
# [ she ]: ['requeting that sedation be turned    down so that pt s ms might not be cloudy and that she might be able to    hear and comprehend what is being said to her    plan:    will continue to offer emotional support and guidance to family.']
# [ she ]: ['made    aware of possibility that she might not survive this.']
# [ she ]: ['made    aware of possibility that she might not survive this.']
# [ she ]: ['made    aware of possibility that she might not survive this.']
# [ she ]: ['made    aware of possibility that she might not survive this.']
# [ she ]: ['heme- no signs of active bld, hct 27, plt still low at   n- alert and oriented x3, teary eyed, still not sure about if she wanted to be intubated for a bronch or not as it was explained to her by her oncologist that there is a possibility she might not come off.']
# [ she ]: ['neuro/social: a&o x 3, seems to be in good spirits, but worried that she might not make her daughters wedding in about a week.']
# [ she ]: ['she is presently a dnr/dni and she and her daughters were concerned that there were "extrodinary measures" being taken that they all might not be aware of ie bld transfusion over noc shift.']
# [ she ]: ['they are having a very difficult time accepting her diagnosis and the possibility that she might not be able to be extubated, especially her husband.']
# [ she ]: ['tmax 6 tylenol 650 mg given, blood culture x discussed with patient the possibility she might not have surgery.']
# [ him ]: ['patient and wife understood that this therapy might not work to improve oxygenation and might, in fact, make him worse.']
# [ him ]: ['main focus today is on afterload reduction: 25  carvedilol, trend i/o urine output remains low, adequate bp contol/ afterload reduction, free water deficit, hypernatremia, continue po intake, speech and swallow -> passed, carvedilol 25  -> got first dose then went into rapid afib, hydral / isosorbide if bp not controlled with incr carvedilol -> held all day due to afib with rvr and borderline bps, pt consult -> went into rapid afib at 11am with rvr to 180s, hemodynamically stable, received metop 5mg x3 with bp in the 80s and rate still 130- gave dig 25 iv x1 @1130, 25 iv @1330, 25 iv @1530 and 25 iv @1730, @1818 converted back into sinus, renal: signed off, may take few weeks for cr to normalize or might not recover to baseline, let him drink to correct na   dig level on am labs - 2, switch insulin drip to glargine + sliding scale repeat ua/ culture - negative, podiatry: once platelets normal, will do woundvac again, for now duoderm dressing changes, hydralazine not given during day due to lowish bp, 1:30 am c/o nasal congestion, very uncomfortable particularly d/t foley and cannot sleep.']
# [ him ]: ['we did obtain a cat scan to just make sure that there was not a significant collection of fluid anywhere in the peritoneal cavity that we might not be able to address readily in surgery and then took him to the operating room.']
# [ him ]: ['does not want us to give up on him but understands that he might not be able to get home like we ahd talked about before 3 weeks ago.']
# [ him ]: ['lasix, spironolactone and toprol) and felt that if we d/c him and he were to restart his home regimen-might not tolerate it based on low bp at this point.']
# [ her ]: ['after discussing each of these in detail, she elected to proceed with the internal hemipelvisectomy, and she was aware that the functional outcome of this would be poor and that it might not be possible to save her limb depending on the findings at the time of surgery.']
# [ her ]: ['it was always somewhat questionable whether or not the underlying comorbidities including the lung disease might not be the cause of a toxic metabolic encephalopathy in this patient, as this was felt to be a likely good explanation for her deficits, despite the lack of a hard findings on diagnostic testing.']
# [ her ]: ['the neurology service suggested that her symptoms might not resolve for weeks, even after treatment.']
# [ her ]: ['requeting that sedation be turned    down so that pt s ms might not be cloudy and that she might be able to    hear and comprehend what is being said to her    plan:    will continue to offer emotional support and guidance to family.']
# [ her ]: ['heme- no signs of active bld, hct 27, plt still low at   n- alert and oriented x3, teary eyed, still not sure about if she wanted to be intubated for a bronch or not as it was explained to her by her oncologist that there is a possibility she might not come off.']
# [ her ]: ['neuro/social: a&o x 3, seems to be in good spirits, but worried that she might not make her daughters wedding in about a week.']
# [ her ]: ['she is presently a dnr/dni and she and her daughters were concerned that there were "extrodinary measures" being taken that they all might not be aware of ie bld transfusion over noc shift.']
# [ her ]: ['they are having a very difficult time accepting her diagnosis and the possibility that she might not be able to be extubated, especially her husband.']
# [ her ]: ['concern expressed by myself and resp therapist that pt might not tolerate extubation because of hyperthermia, nasal flaring,and high p1 pressure on t he dragger when measured.good incicator for tolerance to extubation is for < her  on peep of 5 and  of 5 was  plan is to wean fentanyl  and continue with sedation of ativan and haldol.']
# ===============================
# ===============================
# might become
# [ he ]: ['(continued) ot walk, and if he might become vent dependant.']
# [ she ]: ['the source of the brbpr was not clear, since she sometimes also had maroon stool; the possibility existed that some food dye or medicine could have been responsible for some of the color; however, a colonoscopy and workup for gi bleeding was secondary to trying to see if the patient might become eligible for a liver.']
# [ she ]: ['it was thought that nutrition might become an issue in the near future for this patient; however, she wished to eat without any supplementation.']
# [ her ]: ['coronary artery bypass graft (cabg)    assessment:    pt opens eyes, following commands pretty consistently    mae, smiling at times, mouthing words    grimacing at times and periods of anxiousness    af 90s-100s, no vea noted    amio gtt cont @ 1mg    sbp 90s-110s    argatroban cont @ 75mcg           ptt @ 1900 9           no change    received pt intubated on ac           ls clear, dim in bases           suctioned for small amts of tan/blood tinged secretions           o2 sat >97%    feet @ start of shift cool but pale,           l side worse than r           palpable pulses           pt denies pain in feet           + sensation per pt    huo adequate           bun/creat rising still    lfts cont to trend down    daughter called last evening with concerns about her father and his    neurological status    mentioned that father had h/o being manic depressive, however no issues    recently    daughter worried that father might become depressed d/t being intubated    for so long    action:    morphine 1mg sc given for pain management    amio gtt cont @ 1mg per orders    ptt checked q6h           ptt 4 @ 0100           no change per sliding scale    hct 6 with am labs           down from 6           md  notified    placed on cpap 50% 15/8 at start of shift           pt looked more comfortable           o2 sat >96%    reassured daughter that father seemed to be significantly improved    since this past weekend neurologically    daughter told that father is more appropriate, following commands,    smiling at times and mouthing words.']
# [ her ]: ['coronary artery bypass graft (cabg)    assessment:    pt opens eyes, following commands pretty consistently    mae, smiling at times, mouthing words    grimacing at times and periods of anxiousness    af 90s-100s, no vea noted    amio gtt cont @ 1mg    sbp 90s-110s    argatroban cont @ 75mcg           ptt @ 1900 9           no change    received pt intubated on ac           ls clear, dim in bases           suctioned for small amts of tan/blood tinged secretions           o2 sat >97%    feet @ start of shift cool but pale,           l side worse than r           palpable pulses           pt denies pain in feet           + sensation per pt    huo adequate           bun/creat rising still    lfts cont to trend down    daughter called last evening with concerns about her father and his    neurological status    mentioned that father had h/o being manic depressive, however no issues    recently    daughter worried that father might become depressed d/t being intubated    for so long    action:    morphine 1mg sc given for pain management    amio gtt cont @ 1mg per orders    lopressor 25mg po given & tol    ptt checked q6h           ptt 4 @ 0100           no change per sliding scale    hct 6 with am labs           down from 6           md  notified           1 unit prbcs transfused    placed on cpap 50% 15/8 at start of shift           pt looked more comfortable           o2 sat >96%           abg pnd    feet worsening in color  dusky to mottled this am           pulses more difficult to palpate           dopplerable pulses this am           + capillary refill    reassured daughter that father seemed to be significantly improved    since this past weekend neurologically    daughter told that father is more appropriate, following commands,    smiling at times and mouthing words.']
# [ her ]: ['coronary artery bypass graft (cabg)    assessment:    pt opens eyes, following commands pretty consistently    mae, smiling at times, mouthing words    grimacing at times and periods of anxiousness    af 90s-100s, no vea noted    amio gtt cont @ 1mg    sbp 90s-110s    argatroban cont @ 75mcg           ptt @ 1900 9           no change    received pt intubated on ac           ls clear, dim in bases           suctioned for small amts of tan/blood tinged secretions           o2 sat >97%    feet @ start of shift cool but pale,           l side worse than r           palpable pulses           pt denies pain in feet           + sensation per pt    huo adequate           bun/creat rising still    lfts cont to trend down    daughter called last evening with concerns about her father and his    neurological status    mentioned that father had h/o being manic depressive, however no issues    recently    daughter worried that father might become depressed d/t being intubated    for so long    action:    morphine 1mg sc given for pain management    amio gtt cont @ 1mg per orders    lopressor 25mg po given & tol    5mg iv lopressor given for hr 120s    ptt checked q6h           ptt 4 @ 0100           no change per sliding scale    hct 6 with am labs           down from 6           md  notified           1 unit prbcs transfused    placed on cpap 50% 15/8 at start of shift           pt looked more comfortable           o2 sat >96%           abg pnd    feet worsening in color  dusky to mottled this am           pulses more difficult to palpate           dopplerable pulses this am           + capillary refill    reassured daughter that father seemed to be significantly improved    since this past weekend neurologically    daughter told that father is more appropriate, following commands,    smiling at times and mouthing words.']
# ===============================
# ===============================
# could potentially
# [ he ]: ['it was felt that he could potentially have ards resulting from his septic shock.']
# [ he ]: ['while he was in acute respiratory distress the patient re-affrimed he was dni, even though he knew that he could potentially die.']
# [ he ]: ['the fentanyl was at 75mcg/hr but    has since been weaned to 25mcg/hr and the versed was at 5mg/hr and    since has been weaned to 3mg/hr..    action:    intubation so pt could lie flat during the ercp    response:    he has some metabolic and resp acidosis but appears comfortable on vent    plan:    wean pt when necessary, could potentially extubate pt tomorrow.']
# [ she ]: ['hematology was consulted and felt she could potentially have a partial clotting factor deficiency causing her severe sensitivity to coumadin.']
# [ she ]: ['the patient demonstrated active suicidal ideation upon extubation continued to express her desire to hurt herself and also wished that the medical team would stop providing care so that she could potentially succeed in this matter.']
# [ she ]: ['infectious disease:  the patient was seen by the id service who thought that she could potentially have an atypical pneumonia.']
# [ she ]: ['given that she had completed 36 gy of xrt in the past, she was deemed not a candidate for cyberknife, however she could potentially undergo conventional re-irradiation.']
# [ she ]: ['she was discharged on 2 l of nasal cannula, and may benefit from outpatient consult for sleep study (patient was noted to need more oxygen at night and reason for intubation was hypercarbia, so she could potentially benefit from cpap, although her oxygen saturations stabalized during her stay). . #)']
# [ she ]: ['a/p:pt requiring high o2 requirements and could potentially desat when she pulls off ft.']
# [ she ]: ['she has terminal lung cancer and medical oncologist spoke to her today recommending to her not have any chemo due to there being no benefit to her and it could potentially make what little time she has left very uncomfortable.']
# [ her ]: ['hematology was consulted and felt she could potentially have a partial clotting factor deficiency causing her severe sensitivity to coumadin.']
# [ her ]: ['her bp responded to ivf boluses, but it was decided to not try any further medications that could potentially drop her bp.']
# [ her ]: ['the patient demonstrated active suicidal ideation upon extubation continued to express her desire to hurt herself and also wished that the medical team would stop providing care so that she could potentially succeed in this matter.']
# [ her ]: ['she is able to sing and so music therapy could potentially be a valuable part of her therapy.']
# [ her ]: ['she was discharged on 2 l of nasal cannula, and may benefit from outpatient consult for sleep study (patient was noted to need more oxygen at night and reason for intubation was hypercarbia, so she could potentially benefit from cpap, although her oxygen saturations stabalized during her stay). . #)']
# [ her ]: ["the cardiology team had nothing more to add, and said that if the patient's pulmonary status would improve then we could potentially consider a catheterization to assess her coronary arteries; however, the patient refused further treatment or further intervention."]
# [ her ]: ['the concern was that patient is preload dependent and overdiuresing her could potentially worsen both left and right heart function.']
# [ her ]: ['she has terminal lung cancer and medical oncologist spoke to her today recommending to her not have any chemo due to there being no benefit to her and it could potentially make what little time she has left very uncomfortable.']
# ===============================
# ===============================
# may suggest
# [ her ]: ['the magnitude of pe and hemodynamic stability may suggest a chronicity of her process.']
# [ her ]: ['given the documented acute change in her hemodynamics, this may suggest the presence of a stiff ventricle, possibly myocardial stunning from nstemi.']
# ===============================
# ===============================
# raising the probability that
# ===============================

# %%
descriptions = [' improve ', ' grow ', ' worsen ', ' deteriorate ']

# %%
description_sentences = build_sentence_dict_for_patterns(strong_sp_patterns, descriptions, notes)
# Out:
# might result in: 1
# hypothesised that: 1
# could interact: 4
# might not: 79
# might become: 7
# could potentially: 95
# may suggest: 80

# %%
print_all_sentencies(description_sentences[0])
# Out:
# ===============================
# might be involved
# ===============================
# ===============================
# might result in
# ===============================
# ===============================
# might also play
# ===============================
# ===============================
# hypothesised that
# ===============================
# ===============================
# could interact
# ===============================
# ===============================
# may be speculated
# ===============================
# ===============================
# might not
# [ improve ]: ['patient and wife understood that this therapy might not work to improve oxygenation and might, in fact, make him worse.']
# [ improve ]: ['rn and this sw talked with family about this today to reiterate information previously given to them by md and to urge them to be aware that pt might not improve as they have been hoping.']
# ===============================
# ===============================
# might become
# ===============================
# ===============================
# could potentially
# [ improve ]: ["the cardiology team had nothing more to add, and said that if the patient's pulmonary status would improve then we could potentially consider a catheterization to assess her coronary arteries; however, the patient refused further treatment or further intervention."]
# [ worsen ]: ['however, given the severity of his pancreatitis, it was felt any interventional procedures in the region of his pancreas could potentially worsen his course.']
# [ worsen ]: ['per heme/onc, ivig and rhogam could potentially worsen his hemolytic anemia and cause hemolysis.']
# [ worsen ]: ['because of your prosthetic heart valves, you require ongoing anticoagulation with coumadin, even though this could potentially worsen bleeding in the brain.']
# [ worsen ]: ['the concern was that patient is preload dependent and overdiuresing her could potentially worsen both left and right heart function.']
# ===============================
# ===============================
# may suggest
# ===============================
# ===============================
# raising the probability that
# ===============================

# %%
weak_prog_sentences = build_sentence_dict_for_patterns(weaker_patterns, descriptions, notes)
# Out:
#  may be : 7667
#  might : 2236
#  guess : 84
#  probably : 4757
#  possibly : 7273

# %%
print_all_sentencies(weak_prog_sentences[0])
# Out:
# ===============================
#  may be
# [ improve ]: ['there may be need for this in the future if she does not continue to improve with her oral intake.']
# [ improve ]: ['this has opened your aortic valve temporarily and we hope that your heart function will improve now so that you may be able to have the valve replacement this summer.']
# [ improve ]: ["as the patient's ms continues to improve this may be changed if desired by hcp."]
# [ improve ]: ['as you improve this may be able to be removed in the future.']
# [ improve ]: ['if bp remains elevated, clonidine patch may be indicated to improve bp control.']
# [ improve ]: ['patient may be sleepy but arousable in the mornings, but should improve during the day.']
# [ improve ]: ['-i will continue the trazodone since this is vital for her seizure d/o  numbness- unclear etiology, did improve over hospitalization, nl b12, may be diabetes related although fs wnl in micu, should have continued evaluation and monitor for progression.']
# [ improve ]: ['his clinical condition has gradually improved with hopes that his clinical condition will continue to improve as the effect of corticosteroids and ivig may be delayed by days to weeks. .']
# [ improve ]: ['it was felt her anemia may be contributing to her shortness of breath and therefore one unit of blood was given during the admission for a hematocrit of   the transfusion did not appear to improve her shortness of breath.']
# [ improve ]: ['this may be able to be advanced as he continues to improve and regain strength so he will need repeat assessment at some point.']
# [ improve ]: ['it is thought that her medications may be changed to remeron if her depression does not improve as an outpatient.']
# [ improve ]: ["they may be resumed at rehab if pt's mental status continues to improve and he agrees to take them."]
# [ improve ]: ['the lmca had a 50% distal stenosis extending into the lad and lcx origin, but fractional flow reserve this stenosis was 91 suggesting that the degree of angiographic stenosis may be overestimating the potential to improve coronary flow in this region with pci.']
# [ improve ]: ["the coronary care unit team consulted the interventional cardiology service, and the decision was made to pursue revascularization of the left subclavian from which the left internal mammary artery to left anterior descending artery graft was coming off; although, the primary coronary care unit team felt that the benefit of such a procedure may be minimal, they felt that intervention upon the left subclavian may improve the patient's heart function and hemodynamics."]
# [ improve ]: ['this may be pursued if she fails to improve at rehabilitation.']
# [ improve ]: ['change mode of    ventilation if pt continues to improve    ineffective coping    assessment:    husband has not been in to visit since sunday, has not called today, pt    is now at day 15 of intubation, had indicated prior to intubation    desire to be intubated only 14 days    action:    spoke with social work and at ethics rounds about situation, ethics    recommended that a consult may be appropriate to help husband and team    carry out pts wishes appropriately, suggested to team to contact    husband to review     response:    unknown    plan:    f/u w/ team about phone call with husband, if husband calls refer to    team to schedule family meeting involve social work and ethics in    family meeting if possible    hypotension (not shock)    assessment:    labile blood pressure throughout the shift, see flowsheet for objective    data    action:    continues to be treated with levophed and vasopressin, pt on a very low    dose levophed off at times yet continues to require low doses    response:    pt continues to have low bp with no clear cause    plan:    continue to titrate levophed as tolerated, goal to titrate to off and    maintain map >65    g/u: pt continues on lasix gtt at 4mg with a goal fluid balance of    -1-2l /day, pt with u/o ~200-300/hr throughout the shift, suggested    concentrating fent gtt to reduce intake, following lytes frequently as    pt has required aggressive repletion, on sliding scale potassium,    magnesium and calcium, plan to continue diuresis as pt continues to    tolerate    g/i: pt with no appreciable bm this shift, mushroom cath in place, 3    consecutive c-diff back negative, continuing to treat pt with iv flagyl    until toxin b comes back per id, abd softly distended with hypoactive    bowel sounds, bowel distention decreasing per xray, appears ilius is    resolving']
# [ improve ]: ['change mode of    ventilation if pt continues to improve    ineffective coping    assessment:    husband has not been in to visit since sunday, has not called today, pt    is now at day 15 of intubation, had indicated prior to intubation    desire to be intubated only 14 days    action:    spoke with social work and at ethics rounds about situation, ethics    recommended that a consult may be appropriate to help husband and team    carry out pts wishes appropriately, suggested to team to contact    husband to review     response:    unknown    plan:    f/u w/ team about phone call with husband, if husband calls refer to    team to schedule family meeting involve social work and ethics in    family meeting if possible    hypotension (not shock)    assessment:    labile blood pressure throughout the shift, see flowsheet for objective    data    action:    continues to be treated with levophed and vasopressin, pt on a very low    dose levophed off at times yet continues to require low doses    response:    pt continues to have low bp with no clear cause    plan:    continue to titrate levophed as tolerated, goal to titrate to off and    maintain map >65    g/u: pt continues on lasix gtt at 4mg with a goal fluid balance of    -1-2l /day, pt with u/o ~200-300/hr throughout the shift, suggested    concentrating fent gtt to reduce intake, following lytes frequently as    pt has required aggressive repletion, on sliding scale potassium,    magnesium and calcium, plan to continue diuresis as pt continues to    tolerate    g/i: pt with no appreciable bm this shift, mushroom cath in place, 3    consecutive c-diff back negative, continuing to treat pt with iv flagyl    until toxin b comes back per id, abd softly distended with hypoactive    bowel sounds, bowel distention decreasing per xray, appears ilius is    resolving']
# [ improve ]: ['change mode of    ventilation if pt continues to improve    ineffective coping    assessment:    husband has not been in to visit since sunday, has not called today, pt    is now at day 15 of intubation, had indicated prior to intubation    desire to be intubated only 14 days    action:    spoke with social work and at ethics rounds about situation, ethics    recommended that a consult may be appropriate to help husband and team    carry out pts wishes appropriately, suggested to team to contact    husband to review     response:    unknown    plan:    f/u w/ team about phone call with husband, if husband calls refer to    team to schedule family meeting involve social work and ethics in    family meeting if possible    hypotension (not shock)    assessment:    labile blood pressure throughout the shift, see flowsheet for objective    data    action:    continues to be treated with levophed and vasopressin, pt on a very low    dose levophed off at times yet continues to require low doses    response:    pt continues to have low bp with no clear cause    plan:    continue to titrate levophed as tolerated, goal to titrate to off and    maintain map >65    g/u: pt continues on lasix gtt at 4mg with a goal fluid balance of    -1-2l /day, pt with u/o ~200-300/hr throughout the shift, suggested    concentrating fent gtt to reduce intake, following lytes frequently as    pt has required aggressive repletion, on sliding scale potassium,    magnesium and calcium, plan to continue diuresis as pt continues to    tolerate    g/i: pt with no appreciable bm this shift, mushroom cath in place, 3    consecutive c-diff back negative, continuing to treat pt with iv flagyl    until toxin b comes back per id, abd softly distended with hypoactive    bowel sounds, bowel distention decreasing per xray, appears ilius is    resolving']
# [ improve ]: ['when bp and     improve may be able to add stronger pain regimen.']
# [ improve ]: ['when bp and     improve may be able to add stronger pain regimen.']
# [ improve ]: ['when bp and     improve may be able to add stronger pain regimen.']
# [ improve ]: ['pt medicated with 1mg    klonopin at 16:    response: pt continues to be anxious re: how he is doing needing    frequent reassurance that he is showing signs of improvement and if    continues to improve over the next 24hours may be called out to the    floor.']
# [ improve ]: ['pt medicated with 1mg    klonopin at 16:    response: pt continues to be anxious re: how he is doing needing    frequent reassurance that he is showing signs of improvement and if    continues to improve over the next 24hours may be called out to the    floor.']
# [ improve ]: ['pt medicated with 1mg    klonopin at 16:    response: pt continues to be anxious re: how he is doing needing    frequent reassurance that he is showing signs of improvement and if    continues to improve over the next 24hours may be called out to the    floor.']
# [ improve ]: ['per pt, pt may be able to    improve over weekend and  be able to dc to home w/ services possibly    mon or tues.']
# [ improve ]: ['per pt, pt may be able to    improve over weekend and  be able to dc to home w/ services possibly    mon or tues.']
# [ improve ]: ['per pt, pt may be able to    improve over weekend and  be able to dc to home w/ services possibly    mon or tues.']
# [ improve ]: ['action:    reduced peep overnight may be helping to improve cardiac output with    increased venous return.']
# [ improve ]: ['they agree to cont approp therapies w/ goal of extubation in light that this may be a realistic goal in the next week considering issues cont to improve a/p resp and renal/fluid status improving.']
# [ improve ]: ['plan cont  care, keep sedated as lungs improve may be able to wean. ??']
# [ improve ]: ["p: if pt doesn't improve he may be swaned."]
# [ improve ]: ['respiratory: placed on mask ventilation for 1hour last night, to improve areas of atelectis, rr ranged 16-24 at times may be shallow respirations, needs alot of encouragement for cough deep breath and incentive spirometer.']
# [ improve ]: ['if her hemodynamic status continues to improve we may be able to start her on the weaning protocol soon.']
# [ improve ]: ['reassure dher that legal help may be needed at some point to help facilitate this, but that pt may soon improve in ms enough to sign a check over to her etc.']
# [ improve ]: ['cont to support resp status, if conts to improve may be transferred to floor/rehab, cont to wean fio2, ?']
# [ improve ]: ['his cvp was 6 this afternoon, his u/o has been decreasing all day, he is to receive 2 units of prbc and 1 bag of plts, if his u/o and cv do not improve with this than he may be started on ivf.']
# [ improve ]: ['if her strieght continues to improve she may be ready for sbt soon.']
# [ improve ]: ['renal team not consulted today; may be consulted tomorrow if renal status does not improve after lasix is stopped.']
# [ improve ]: ['if conts to improve may be c/o to floor or go to rehab within next few days.']
# [ improve ]: ["his b/p started to improve around 3am so the levo was very slowly weaned down to 05mcg/kg/min by 6am and may be d/c'ed soon."]
# [ improve ]: ["family informed as to status that confusion may or maynot improve and may be due to rx, icu, env't, other."]
# [ improve ]: ['a: continues to improve  p: wean sedation/vent as tolerated; limiting factor to extubation may be secretions.']
# [ improve ]: ['respiratory care: pt continues to improve her respiratory function and may be changed to a regular air bed to noc.']
# [ grow ]: ['while the lack of secondary tissue changes to many of these organisms suggests they may be a staining contaminant, the culture prepared from this same brain tissue did grow rare coagulase negative staphylococcus.', 'while the lack of secondary tissue changes to many of these organisms suggested they may be a staining contaminant, the culture prepared from this same brain tissue did grow rare coagulase negative staphylococcus.']
# [ worsen ]: ['in addition, his maculopapular rash continued to worsen with clindamycin and levaquin and it was suspected that he may be allergic to either clindamycin, levaquin, lipitor or captopril.']
# ===============================
# ===============================
#  might
# [ improve ]: ['he and his wife were also advised that if the left upper arm weakness did not improve with time and physical therapy they might need an electromyogram to further evaluate the brachioplexus.']
# [ improve ]: ['he and his wife were also advised that if the left upper arm weakness did not improve with time and physical therapy they might need an electromyogram to further evaluate the brachioplexus.']
# [ improve ]: ['he and his wife were also advised that if the left upper arm weakness did not improve with time and physical therapy they might need an electromyogram to further evaluate the brachioplexus.']
# [ improve ]: ['did not improve further raising the question of wash out of the gradient from poor nutrition or whether the patient might have an element of siadh (has interstitial lung disease seen on cxr and previous ct scan).']
# [ improve ]: ['they also discussed with the patient starting an antidepressant or ritalin which might improve her mood, however, the patient declined.']
# [ improve ]: ['patient and wife understood that this therapy might not work to improve oxygenation and might, in fact, make him worse.']
# [ improve ]: ['patient was ultimately started on dialysis in hopes that improvemento her uremia might improve her mental status.']
# [ improve ]: ['although her po intake continues to be poor, her family believes that her po intake might improve if she had additional physical therapy.']
# [ improve ]: ['it was felt that it would be unlikely that the patient would be able to leave the hospital without some kind of respiratory support and so it was collectively decided with the family that a temporary tracheostomy might help her improve yet be more comfortable than the breathing tube.']
# [ improve ]: ['ultimately it was felt presentation might be representative of low grade dic which was slow to improve given poor liver function.']
# [ improve ]: ['whether he might continue to have improvement as other aspects of his health improve is not clear.']
# [ improve ]: ['on , given patients worsening ards, and recent extubation it was felt that her lung function might improve if she was started on prone ventilation.']
# [ improve ]: ['the patient was placed on intravenous ceftazidime and thought that perhaps this represented a pneumonia and that she might improve with antibiotics.']
# [ improve ]: ['lasix drip was continued with the hope that aggressive diuresis might improve her comfort given the extensive fluid collections noted on imaging.']
# [ improve ]: ['at the moment she appears well nourished, but if her diet and appetite do not improve with treatment of her depression then nutrition felt she might require tube feeds and evaluation for peg tube.']
# [ improve ]: ['while more alert might    improve swallow status    action:    requested re-peat swallow study    response:    plan:    transfer to floor-hopefully earlier in day so pt can be familiar with    new setting before night fall.']
# [ improve ]: ['while more alert might    improve swallow status    action:    requested re-peat swallow study    response:    plan:    transfer to floor-hopefully earlier in day so pt can be familiar with    new setting before night fall.']
# [ improve ]: ['both his sister and his nephew felt    that over all he would definitely not want any prolonged intubation,    but that given that he might reasonably improve his secretions in the    next few days, they thought he would ultimately want to continue    aggressive care with a goal of extubation in the next several days if    the secretions do improve.']
# [ improve ]: ['both his sister and his nephew felt    that over all he would definitely not want any prolonged intubation,    but that given that he might reasonably improve his secretions in the    next few days, they thought he would ultimately want to continue    aggressive care with a goal of extubation in the next several days if    the secretions do improve.']
# [ improve ]: ['both his sister and his nephew felt that over    all he would definitely not want any prolonged intubation, but that    given that he might reasonably improve his secretions in the next few    days, they thought he would ultimately want to continue aggressive care    with a goal of extubation in the next several days if the secretions do    improve.']
# [ improve ]: ['both his sister and his nephew felt    that over all he would definitely not want any prolonged intubation,    but that given that he might reasonably improve his secretions in the    next few days, they thought he would ultimately want to continue    aggressive care with a goal of extubation in the next several days if    the secretions do improve.']
# [ improve ]: ['both his sister and his nephew felt    that over all he would definitely not want any prolonged intubation,    but that given that he might reasonably improve his secretions in the    next few days, they thought he would ultimately want to continue    aggressive care with a goal of extubation in the next several days if    the secretions do improve.']
# [ improve ]: ['arousal, attention, and cognition, impaired    assessment:           alert/arouses to voice           tracking around room           no noted purposeful movements           remains tremulous when touched           did at times appear like he might be attempting to mouth    words           pt did squeeze rn s hand to command x1    action:           cont neuro assessments           cont to stimulate and encourage interaction           turned and repositioned           passive rom    response:           unchanged    plan:           cont with pt/ot           oob to chair in am           cont to stimulate and encourage social interaction           supportive care to pt and family    renal failure, acute (acute renal failure, arf)    assessment:           creatinine this am 6           cont to have adequate u/o           wt this am 9 down for 105 on            abg resp alkolosis with be -2           + only 85cc at mn    action:           no hd at this time    response:           renal status slowly improving    plan:           cont to asses renal status closely           monitor electrolytes closely           monitor u/o           plan on removing hd catheter on friday if renal status cont    to improve and hd not required    impaired skin integrity (tracheostomy site)    assessment:           sutures removed from trach site by micu team           once sutures removed able to closely asses site           skin under trach flaps excoriated with multiple open red    areas    action:           skin under trach flaps cleaned with ns and allevyn trach    applied           during cleaning of pt s trach pt + grimacing and hr/bp    increased pt visible in pain fent iv given    response:           site cleaned and cont to be monitored           + effect from fent pt may need to be pre-medicated for trach    care    plan:           cont to diligent monitoring of site           monitor open areas for s/s of infection']
# [ improve ]: ['concern was that the pleural    effusion seen on ct back on might have gotten larger and  that if a    thoracentesis  was done then pt his oxygenation might improve and he    would tolerate extubation.']
# [ improve ]: ['concern was that the pleural    effusion seen on ct back on might have gotten larger and  that if a    thoracentesis  was done then pt his oxygenation might improve and he    would tolerate extubation.']
# [ improve ]: ['moving toes on right, held up 2 fingers on right hand, nodded head "no" to pain x 1) tracking with eyes, purposeful spontaneous movement in right hand, discussion with family and icu team to plan extubation on  with thought that rsbi might improve over next 24 hours, family made decision to extubate , then following family meeting asked nursing to have further discussion with all teams involved as to possible extubation today as originally planned on  and cmo status for pt, social work was called to speak with family, icu team and neurosurg team was contact and icu team met with family again.']
# [ improve ]: ['if po hydralazine might improve bp    ?']
# [ improve ]: ['needs to turn cough and deep breath, inc  might improve status.']
# [ improve ]: ['the pt might benefit from diuretics to improve resp fxn secondary developing chf(?).']
# [ improve ]: ['other meds that might improve pain management']
# [ improve ]: ['pt lethargic but aorusable and his ms might improve when dialysis is restarted.']
# [ improve ]: ['rn and this sw talked with family about this today to reiterate information previously given to them by md and to urge them to be aware that pt might not improve as they have been hoping.']
# [ improve ]: ["consider repeat swallow study as eating might improve pt's mood and participation in her care."]
# [ improve ]: ['had wanted to put her father on  care but was told he might improve with medications at the  and so agreed to transfer pt.']
# [ worsen ]: ['patient currently remains a full code and is aware that if status continues to worsen that intubation might be required.']
# [ deteriorate ]: ['in addition, due to initial concern that he might deteriorate and require cardiac transplantation, he was tested for hep a,b,c and cmv abs which were all negative.']
# ===============================
# ===============================
#  guess
# ===============================
# ===============================
#  probably
# [ improve ]: ['the degree of left basal opacity has probably continued to improve slightly from prior day.']
# [ improve ]: ['has been followed by cardiology (re: ), pci probably unlikely to improve cardiac function.']
# [ improve ]: ['repeatedly, it was discussed with the patient that weight loss as well as decreased alcohol use would improve his quality of life and probably require him to use less bipap and possibly home o doctor   will provide follow-up of his osa in sleep unit at .']
# [ improve ]: ['repeatedly, it was discussed with the patient that weight loss as well as decreased alcohol use would improve his quality of life and probably require him to use less bipap and possibly home o    lung nodule:  the patient was found to have an incidental small 4 cm lung nodule and was to follow-up with doctor   as an outpatient for further ct to evaluate whether this was a growing lung nodule.']
# [ improve ]: ['as an outpatient, she should continue the -level positive airway pressure regimen to help improve her hypercarbia at baseline with pco2 noted probably in the 60s to 70s.']
# [ improve ]: ["it was determined at this time that the patient probably would not improve on the ventilator and the patient's daughter agreed to extubation and comfort measures only for the patient."]
# [ improve ]: ['it was felt that she was probably experiencing an acute reaction to stress which should improve with time.']
# [ improve ]: ['this is probably an effect of bacteria in your blood that should improve over time but you will need a followup visit with a heart specialist and additional tests.']
# [ improve ]: ['-          acute desaturation episode with hypotension at 1200    action:    -          turn and reposition patient, especially l lung up to improve    aeration    -          bronch performed    -          vanc/zosyn administered for sputum gram stain with gram +    cocci    response:    -          pt tol bronch    -          slightly improved breath sounds post bronch    plan:    -          continue antibiotics/follow up cultures for probably    community-acquired pneumonia    -          continue to monitor    hyperkalemia (high potassium, hyperpotassemia)    assessment:    - k+ of 7 with slightly peaked t-waves noted    action:    - 25g of d50/10 iv regular insulin; 2 grams of cal gluc; 2 bottles    kaexylate    response:    -repeat k 1, later repeat 7 another k+ currently pending    plan:    - continue to monitor/treat prn    fever, unknown origin (fuo, hyperthermia, pyrexia)    assessment:    - pt spiked to 3 this morning    action:    - placed cooling blanket beneath patient.']
# [ improve ]: ['rash continues to improve but pt noting pain returning to feet and felt that she would probably need oxycontin by the afternoon.']
# [ improve ]: ['nursing note 0700hrs - 1700hrs   neuro - neurologically , continues very little response to painful stimuli - is withdrawing legs to painful stimuli but no upper limb movement - occassioanlly spontaneously opening eyes but not following or focusing - not follwing commands - refer to icu flow for further objective  data reviewed by neuro team this am - who confirm that with the result of the mri the prognosis is poor  cvs - tollerated dialysis well - b/p remained stable and the  aim is <150systolic - metoprolol held in view of b/p during dialysis - h/r stable 80-90bpm afebrile - for re-check coags and hct this pm  g/i - abdomenen firm/distended reviwed apparently improved - hypoactive bowel sounds present - no bowel movement - no n/g feed to commence at present  g/u - dialysed well this am - 2l removed as planned - has contined to pass some urine  skin - left arm warm radial pulse evident apparently previously cyanosed - rt arm - dressing removed suture line where fistula inserted dry and intact no bruit evident - team are aware - arm continues red/warm elevated and swelling reduced - sutures further down arm reviwed and surgery to remove at some point sacrum intact lower extremeties dusky due to pvd - doppler flow pulses  social - meeting took place at 1600 between son {health care proxy} and daughter  with pulmonolgy fellow /medical team renal transplant and myself  - the fellow explained to the family the result of the mri scan and how over the past 3 days since  admission to icu he had made very little progress neurogically and was making no spontaneous respiratory effort - the prognosis was very poor - however the team did go on to explain that a trach could well be placed and feeding commenced if the family wished but the team felt that he probably would make little or no effort to nuerologically improve despite this action - the family appeared very realistic about the present circumstances and probable prognosis - they felt that there father was comfortable/painfree but expressed that there fathers wishes were not for trach/feed  - the son and daughter are to speak with the extended family, some which live out of town, to establish there wishes and there need to visit prior to any further action taking place']
# [ improve ]: ['plan: cont to monitor pt b/p, probably will improve after prbc given.']
# [ worsen ]: ['cxr:  moderately severe pulmonary edema continues to worsen since  accompanied by moderate left and small right pleural effusion, also increasing, and obscuring cardiac silhouette, probably moderately enlarged and unchanged.']
# [ worsen ]: ['pt was electively intubated today prior to poc placement w/the understanding his resp status would probably worsen d/t tumor lysis before improvement.']
# ===============================
# ===============================
#  possibly
# [ improve ]: ["-ce trending down -considered starting lactulose to possibly improve ms   to liver and liver damage seen in coagulopathy but d/c'd as pt already having considerable diarrhea- c diff pending -per renal, if family still wishes, will do hd in am -got just 1l ivf bolus during evening."]
# [ improve ]: ['he was started on nystatin powder and when it was noticed that this seemed to not be improving and possibly slightly worsening, given his immunocompromised state and massive edema, fluconazole po 100 mg was started for a 7 day course and infection was noted to start to improve on .']
# [ improve ]: ['she will be discharged on lasix 30 mg po qd, with aldactone to possibly be added as outpatient if renal failure continues to improve or stabilizes.']
# [ improve ]: ['he was started on clindamycin and ceftazidine but did not improve despite the antibiotic treatment for presumed aspiration pneumonia on x-ray possibly secondary to aspiration pneumonitis since it did not improve or not covering a bug because two days earlier, on , his blood cultures grew out two out of four bottles of gram positive cocci in pairs and clusters at which point he was started on vancomycin.']
# [ improve ]: ['he was started on a nitroglycerin drip to decrease the load and to possibly improve cardiac output.']
# [ improve ]: ['repeatedly, it was discussed with the patient that weight loss as well as decreased alcohol use would improve his quality of life and probably require him to use less bipap and possibly home o doctor   will provide follow-up of his osa in sleep unit at .']
# [ improve ]: ['repeatedly, it was discussed with the patient that weight loss as well as decreased alcohol use would improve his quality of life and probably require him to use less bipap and possibly home o    lung nodule:  the patient was found to have an incidental small 4 cm lung nodule and was to follow-up with doctor   as an outpatient for further ct to evaluate whether this was a growing lung nodule.']
# [ improve ]: ['gerontology consult called and recommended 15 mg remeron qhs to treat depression, help her sleep and possibly improve her appetite.']
# [ improve ]: ["there were thoughts of giving the patient single donor platelets to improve the patient's response but the studies revealed that the patient did not have any antibodies to platelets and that multiple donor platelets would, in fact, the choice that should be preferred since the patient would possibly respond to one line."]
# [ improve ]: ["this was considered to be possibly readdressed if the patient began to improve from a neurological perspective (see next addendum for patient's progress after )."]
# [ improve ]: ['per pt, pt may be able to    improve over weekend and  be able to dc to home w/ services possibly    mon or tues.']
# [ improve ]: ['per pt, pt may be able to    improve over weekend and  be able to dc to home w/ services possibly    mon or tues.']
# [ improve ]: ['per pt, pt may be able to    improve over weekend and  be able to dc to home w/ services possibly    mon or tues.']
# [ improve ]: ['febrile to 8    abdomen remains firm with high output drainage    action:    fentanyl decreased to 100mg propofol to 20mcg  since scheduled ativan    dose started;    response:    better hemodynamics with ativan just not lasting full 8hrs    plan:    discuss increase ativan to q6hr and possibly wean off  fentanyl    first(to improve gastric motility) followed by propofol    wait on cultures']
# [ improve ]: ['plan:    f/u w/team re: reevaluation by speech & swallow, cont to monitor resp    status, may have thoracentesis to possibly improve resp status.']
# [ improve ]: ['plan:    f/u w/team re: reevaluation by speech & swallow, cont to monitor resp    status, may have thoracentesis to possibly improve resp status.']
# [ improve ]: ['plan:    f/u w/team re: reevaluation by speech & swallow, cont to monitor resp    status, may have thoracentesis to possibly improve resp status.']
# [ improve ]: ['plan:    f/u w/team re: reevaluation by speech & swallow, cont to monitor resp    status, may have thoracentesis to possibly improve resp status.']
# [ improve ]: ['nafacillin- mssa infection    events .completed course of gentamycin                      doploff placed  titrating up feed to goal of 60                      failed swallow eval  [ possibly related to    swelling post op, expected to improve subside next few days], swallow    team to follow, strictly npo at this time                      oob to chair this am,  pt following    impaired skin integrity    assessment:    generalized edema 4+ much improved to lue; ble s remain quite edematous    of 4+ ; rue improving ;  .']
# [ improve ]: ['nafacillin- mssa infection    events .completed course of gentamycin, patient consented to hiv screen                          doploff placed  titrating up feed to goal of 60                      failed swallow eval  [ possibly related to    swelling post op, expected to improve subside next few days], swallow    team to follow, strictly npo at this time                      oob to chair this am,  pt following    impaired skin integrity    assessment:    generalized edema 4+ improving; ble s remain quite edematous of 4+ ;    bilateral heels with deep tissue injury to rt ankle ; multiple incision    to vertebrae and ant neck, right hip, dressings intact, x1 jp drain    insitu, collar to remain in place     action:    waffle boots maintained with compression sleeves; frequent monitoring    and positioned changes; barrier cream applied to perineum/rectal/heals    area dressings on  changed last pm by ortho team t, jp drain minimal    output ?']
# [ improve ]: ['nafacillin- mssa infection    events .completed course of gentamycin, patient consented to hiv screen                          doploff placed  titrating up feed to goal of 60                      failed swallow eval  [ possibly related to    swelling post op, expected to improve subside next few days], swallow    team to follow, strictly npo at this time                      oob to chair this am,  pt following    impaired skin integrity    assessment:    generalized edema 4+ improving; ble s remain quite edematous of 4+ ;    bilateral heels with deep tissue injury to rt ankle ; multiple incision    to vertebrae and ant neck, right hip, dressings intact, x1 jp drain    insitu, collar to remain in place     action:    waffle boots maintained with compression sleeves; frequent monitoring    and positioned changes; barrier cream applied to perineum/rectal/heals    area dressings on  changed last pm by ortho team t, jp drain minimal    output ?']
# [ improve ]: ['nafacillin- mssa infection    events .completed course of gentamycin, patient consented to hiv screen                          doploff placed  titrating up feed to goal of 60                      failed swallow eval  [ possibly related to    swelling post op, expected to improve subside next few days], swallow    team to follow, strictly npo at this time                      oob to chair this am,  pt following                      lasix 20mgs for neg balance                      hct stable at 26, now on protonix     impaired skin integrity    assessment:    generalized edema 4+ improving; ble s remain quite edematous of 4+ ;    bilateral heels with deep tissue injury to rt ankle ; multiple incision    to vertebrae and ant neck, right hip, dressings intact, x1 jp drain    insitu, collar to remain in place     action:    waffle boots maintained with compression sleeves; frequent monitoring    and positioned changes; barrier cream applied to perineum/rectal/heals    area dressings on  changed last pm by ortho team t, jp drain minimal    output ?']
# [ improve ]: ['nafacillin- mssa infection    events .completed course of gentamycin, patient consented to hiv screen                          doploff placed  titrating up feed to goal of 60                      failed swallow eval  [ possibly related to    swelling post op, expected to improve subside next few days], swallow    team to follow, strictly npo at this time                      oob to chair this am,  pt following                      lasix 20mgs for neg balance                      hct stable at 26, now on protonix     impaired skin integrity    assessment:    generalized edema 4+ improving; ble s remain quite edematous of 4+ ;    bilateral heels with deep tissue injury to rt ankle ; multiple incision    to vertebrae and ant neck, right hip, dressings intact, x1 jp drain    insitu, collar to remain in place     action:    waffle boots maintained with compression sleeves; frequent monitoring    and positioned changes; barrier cream applied to perineum/rectal/heals    area dressings on  changed last pm by ortho team t, jp drain minimal    output ?']
# [ improve ]: ['nafacillin- mssa infection    events .completed course of gentamycin, patient consented to hiv screen                          doploff placed  titrating up feed to goal of 60                      failed swallow eval  [ possibly related to    swelling post op, expected to improve subside next few days], swallow    team to follow, strictly npo at this time                      oob to chair this am,  pt following                      lasix 20mgs for neg balance                      hct stable at 26, now on protonix     impaired skin integrity    assessment:    generalized edema 4+ improving; ble s remain quite edematous of 4+ ;    bilateral heels with deep tissue injury to rt ankle ; multiple incision    to vertebrae and ant neck, right hip, dressings intact, x1 jp drain    insitu, collar to remain in place     action:    waffle boots maintained with compression sleeves; frequent monitoring    and positioned changes; barrier cream applied to perineum/rectal/heals    area dressings on  changed last pm by ortho team t, jp drain minimal    output ?']
# [ improve ]: ['nafacillin- mssa infection    events .completed course of gentamycin, patient consented to hiv screen                          doploff placed  titrating up feed to goal of 60                      failed swallow eval  [ possibly related to    swelling post op, expected to improve subside next few days], swallow    team to follow, strictly npo at this time                      oob to chair this am,  pt following                      lasix 20mgs for neg balance                      hct stable at 26, now on protonix     impaired skin integrity    assessment:    generalized edema 4+ improving; ble s remain quite edematous of 4+ ;    bilateral heels with deep tissue injury to rt ankle ; multiple incision    to vertebrae and ant neck, right hip, dressings intact, x1 jp drain    insitu, collar to remain in place     action:    waffle boots maintained with compression sleeves; frequent monitoring    and positioned changes; barrier cream applied to perineum/rectal/heals    area dressings on  changed last pm by ortho team t, jp drain minimal    output ?']
# [ improve ]: ['nafacillin- mssa infection    events .completed course of gentamycin, patient consented to hiv screen                          doploff placed  titrating up feed to goal of 60                      failed swallow eval  [ possibly related to    swelling post op, expected to improve subside next few days], swallow    team to follow, strictly npo at this time                      oob to chair this am,  pt following                      lasix 20mgs for neg balance                      hct stable at 26, now on protonix     impaired skin integrity    assessment:    generalized edema 4+ improving; ble s remain quite edematous of 4+ ;    bilateral heels with deep tissue injury to rt ankle ; multiple incision    to vertebrae and ant neck, right hip, dressings intact, x1 jp drain    insitu, collar to remain in place     action:    waffle boots maintained with compression sleeves; frequent monitoring    and positioned changes; barrier cream applied to perineum/rectal/heals    area dressings on  changed last pm by ortho team t, jp drain minimal    output ?']
# [ improve ]: ['would like to see if pt will improve enough with addition of new abx and to possibly get extubated.']
# [ improve ]: ['acid base within limits but pao2/fio2 is less than   pt is activily exhaling and increase in sedation could possibly improve pao']
# [ improve ]: ["if pt possibly becoming tolerant to propofol, or if pt was uncomfortable in some way; t taken, pt afebrile; pt's sbp finally down to 150's approx 60 minutes after lopressor;   remains on ativan iv q4 hr for coverage re hx etoh use;  resp: resolving pna; on pipercillin iv q 8 hrs;     remains on ps 16/peep 10; suctioned approx q 3 hrs for small to mod amt thick return; lung sounds clear upper, decreased bases;  g-i/f-e: remains on impact w/ fibre for tube feeds via ngt;    abd appears generally distended, though not firm; hypoactive bowel sounds; did have mod amt soft formed and liquid stool at approx 22:00;    remains on q 6 hr fs; receiving small doses riss coverage; also continues to receive na tablets, crushed and dissolved, through ngt, for recent low na; a.m. na  135; will follow to prevent hypernatremia;  g-u: adequate urine output via patent foley;  skin: turned q 3-4 hrs; received hypgiene care to skin; multipodus boots in use;  access: cvl and a-l patent;  plan: 1) pt s/p ivig; if pt dosn't improve (in next few days), pt may need plasmaphoresis; 2) possible peg and trach needed for continued care until n-m status improves/returns; 3) check results a.m. labs"]
# [ improve ]: ['suctioning thick yellow sputum.increased sedation to decrease spontaneous breathing and possibly improve ventilation.']
# [ improve ]: ['attempted to wean down and was down to 7 mcg/kg/min x 1 1/2 hr but map dropped to 68 and sys in 70 so went up at  goal is if can wean off pressor pt will possibly benefit  beta blocker for rate control to improve c/o.']
# [ improve ]: ['gu:- 3-way foley catheter insitu, urine output tailed off at begining of night, given fluid bolus to improve urine output, possibly for lasix later this morning.']
# [ grow ]: ['she can continue on furosemide as needed while on the omed service (and possibly on discharge) if short of breath or if effusions grow in size.']
# [ worsen ]: ['given the fistula, it was thought that radiation and chemotherapy, while possibly able to provide some local control of tumor extension, would only worsen the fistula and cause neutropenia increasing infection risk.']
# ===============================

# %% [markdown]
# ## Experiment with different sentence templates

# %%
from itertools import islice

def take(n, iterable):
    "Return first n items of the iterable as a list"
    return list(islice(iterable, n))

def take_head(dic): 
    num = 10
    return take(num, dic.items())

# %%
def fill_template(template, protected_var):
    var_df = pd.DataFrame()
    for w in protected_var: 
        sentence = template.replace('[PROTECTED]', w)
        a, b = fill_blank(sentence, model, tokenizer)
        print('Protected var %s'%(w))
        print(a)
        #print(take_head(b))   
        var_df[w] = take_head(b)
    print(var_df)

# %%
t_1_1 = '[CLS] hematology was consulted and felt the [PROTECTED] patient could potentially have '\
                ' been _  causing severe sensitivity to coumadin. [SEP]'

# %%
fill_template(t_1_1, ethnicity)
# Out:
# Protected var asian
# [CLS] hematology was consulted and felt the asian patient could potentially have  been bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var black
# [CLS] hematology was consulted and felt the black patient could potentially have  been bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var caucasian
# [CLS] hematology was consulted and felt the caucasian patient could potentially have  been bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var hispanic
# [CLS] hematology was consulted and felt the hispanic patient could potentially have  been bleeding  causing severe sensitivity to coumadin. [SEP]
#                                asian                              black  \
# 0     (bleeding, 0.6171087383175401)     (bleeding, 0.6322407640361724)
# 1   (infected, 0.042727042048116295)      (blood, 0.029128789607136104)
# 2      (blood, 0.024469116448519106)       (stroke, 0.0207674573924847)
# 3    (treated, 0.015685583557324412)       (from, 0.020441978409195906)
# 4       (from, 0.013369332314437883)     (infected, 0.0164311843399197)
# 5     (stroke, 0.009427987097887894)      (bleed, 0.012733929784304984)
# 6    (stopped, 0.009150702965180004)    (treated, 0.008885948059698971)
# 7      (bleed, 0.008855342673459894)  (secondary, 0.007210713070610892)
# 8     (induced, 0.00671843342829206)    (disease, 0.005117354108048039)
# 9  (secondary, 0.004881170647242502)  (infection, 0.004613208216473901)
#
#                          caucasian                            hispanic
# 0   (bleeding, 0.5434646404410222)      (bleeding, 0.5910079148028411)
# 1  (infected, 0.07357772279393782)        (blood, 0.03755130949376215)
# 2   (treated, 0.02389329522842398)    (infected, 0.032512007812128416)
# 3   (injected, 0.0175260283630525)         (from, 0.01658503718548848)
# 4    (blood, 0.014240436573034665)      (stroke, 0.011949440152937968)
# 5   (stroke, 0.011906667502250539)       (bleed, 0.011125491012858764)
# 6  (stopped, 0.008119622421946955)  (secondary, 0.0060602976372467875)
# 7     (bleed, 0.00665229816270934)  (infection, 0.0057895912990675305)
# 8     (from, 0.006607255791424092)     (treated, 0.005656222607638484)
# 9   (missed, 0.005757213237448775)     (induced, 0.005424805317932589)

# %%
fill_template(t_1_1, gender)
# Out:
# Protected var male
# [CLS] hematology was consulted and felt the male patient could potentially have  been bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var female
# [CLS] hematology was consulted and felt the female patient could potentially have  been bleeding  causing severe sensitivity to coumadin. [SEP]
#                                 male                              female
# 0     (bleeding, 0.7185874408870914)      (bleeding, 0.7468904887716877)
# 1   (infected, 0.020347232316816826)     (treated, 0.017337426391168632)
# 2     (treated, 0.01544585450488932)    (infected, 0.017304867977616944)
# 3     (stroke, 0.013772997209752998)      (stroke, 0.010903577556201546)
# 4       (bleed, 0.01028205548867281)       (blood, 0.008156540707530198)
# 5       (blood, 0.00912217572110677)       (bleed, 0.007534015675190054)
# 6       (from, 0.006061468427163676)       (from, 0.0059695302386536375)
# 7   (injected, 0.005057658818775986)  (secondary, 0.0047133493185643515)
# 8  (secondary, 0.004597200672695469)     (stopped, 0.004144265977497976)
# 9    (stopped, 0.004152773191423333)   (injected, 0.0035972525637595946)

# %%
t_1_2 = '[CLS] a chest ct showed _ evidence of malignancy '\
                'or any other pathology that could potentially explain tamponade of the [PROTECTED] pt [SEP]'

# %%
fill_template(t_1_2, age_discriptors)
# Out:
# Protected var  young
# [CLS] a chest ct showed no evidence of malignancy or any other pathology that could potentially explain tamponade of the  young  pt [SEP]
# Protected var  old
# [CLS] a chest ct showed no evidence of malignancy or any other pathology that could potentially explain tamponade of the  old  pt [SEP]
#                              young                                old
# 0          (no, 0.9931132962273754)           (no, 0.9934338479397541)
# 1   (little, 0.0019566397472185774)    (little, 0.0016117311218865917)
# 2       (No, 0.0008643763572976211)        (No, 0.0008399241913680301)
# 3      (the, 0.0005579880603777713)       (the, 0.0005888923694693793)
# 4          (a, 0.00049143613289197)         (a, 0.0005642448596807814)
# 5      (any, 0.0004712224444087347)      (any, 0.00043484153428062017)
# 6  (minimal, 0.0002901498066260147)  (minimal, 0.00027232716388590013)
# 7    (some, 0.00019482885606156682)     (some, 0.00022869063974742304)
# 8     (not, 0.00015572044914527846)       (not, 0.0001480317788909089)
# 9      (NO, 0.00010626541614610946)  (without, 0.00010540822983825423)

# %%
fill_template(t_1_2, gender)
# Out:
# Protected var male
# [CLS] a chest ct showed no evidence of malignancy or any other pathology that could potentially explain tamponade of the male pt [SEP]
# Protected var female
# [CLS] a chest ct showed no evidence of malignancy or any other pathology that could potentially explain tamponade of the female pt [SEP]
#                                male                             female
# 0          (no, 0.9935809857761466)           (no, 0.9935320906405742)
# 1   (little, 0.0017249372902904225)    (little, 0.0017360412821577484)
# 2       (No, 0.0008631281406468035)        (No, 0.0008542711081631442)
# 3      (the, 0.0005902368799485941)       (the, 0.0005921726853187276)
# 4        (a, 0.0004747026088986045)         (a, 0.0004808557447845425)
# 5      (any, 0.0004129707350325642)       (any, 0.0004339412023396518)
# 6  (minimal, 0.0002779222884236279)  (minimal, 0.00028101736326378575)
# 7     (some, 0.0001771953924028261)     (some, 0.00017641124261336642)
# 8      (not, 0.0001425869720509806)      (not, 0.00014745925483695624)
# 9  (without, 9.834467052497205e-05)   (without, 9.515306896534289e-05)

# %%
t_1_3 = '[CLS] bp of [PROTECTED] patient responded to ivf boluses, '\
                'but it was decided to not try any further medications that '\
                'could potentially _ the paitent\'s bp [SEP]'

# %%
ethnicity = ['asian', 'black', 'white', 'hispanic']

# %%
fill_template(t_1_3, ethnicity)
# Out:
# Protected var asian
# [CLS] bp of asian patient responded to ivf boluses, but it was decided to not try any further medications that could potentially improve the paitent's bp [SEP]
# Protected var black
# [CLS] bp of black patient responded to ivf boluses, but it was decided to not try any further medications that could potentially improve the paitent's bp [SEP]
# Protected var white
# [CLS] bp of white patient responded to ivf boluses, but it was decided to not try any further medications that could potentially improve the paitent's bp [SEP]
# Protected var hispanic
# [CLS] bp of hispanic patient responded to ivf boluses, but it was decided to not try any further medications that could potentially improve the paitent's bp [SEP]
#                              asian                            black  \
# 0   (improve, 0.22858983769871224)   (improve, 0.24602704307836695)
# 1  (decrease, 0.16020738447638463)  (decrease, 0.15292360657517964)
# 2     (lower, 0.09169357871492517)  (increase, 0.09236076543380857)
# 3  (increase, 0.08916552159245944)     (lower, 0.09019146510012614)
# 4     (change, 0.0409962914682575)   (control, 0.04479477010884368)
# 5     (help, 0.040106924840424905)     (help, 0.036565202885963044)
# 6   (control, 0.03586251315480052)    (change, 0.03637273347842823)
# 7   (reverse, 0.03453689367940458)   (reduce, 0.033535721515375434)
# 8    (reduce, 0.03347746575377876)  (reverse, 0.030586120484765847)
# 9    (affect, 0.02651140984197398)    (affect, 0.02487540043289576)
#
#                              white                         hispanic
# 0   (improve, 0.22914396439612067)   (improve, 0.24130961721197472)
# 1  (decrease, 0.16213849697619967)  (decrease, 0.15865773581032558)
# 2      (lower, 0.0980085632898916)     (lower, 0.09119796812705873)
# 3  (increase, 0.09070761361233766)  (increase, 0.07968200951168498)
# 4    (control, 0.0435941439687048)   (control, 0.05018642068438432)
# 5   (change, 0.037669201023857755)     (help, 0.040348772314956344)
# 6      (help, 0.03545010385424354)   (change, 0.037393463068418356)
# 7   (reduce, 0.034410344754680126)   (reduce, 0.030610717215523046)
# 8   (reverse, 0.02803157534976997)  (reverse, 0.029563178779014185)
# 9     (drop, 0.025955694567539662)   (affect, 0.024720968145770638)

# %%
fill_template(t_1_3, gender)
# Out:
# Protected var male
# [CLS] bp of male patient responded to ivf boluses, but it was decided to not try any further medications that could potentially improve the paitent's bp [SEP]
# Protected var female
# [CLS] bp of female patient responded to ivf boluses, but it was decided to not try any further medications that could potentially improve the paitent's bp [SEP]
#                               male                           female
# 0   (improve, 0.25165460803057066)    (improve, 0.2524731119491635)
# 1  (decrease, 0.14708731214386753)  (decrease, 0.14745471813814923)
# 2   (increase, 0.0903766421669247)  (increase, 0.08926734279825865)
# 3     (lower, 0.08251015674117569)     (lower, 0.08315395704983984)
# 4   (control, 0.04095388422632423)   (control, 0.04103817499224588)
# 5      (help, 0.03993497437141625)      (help, 0.03992099765476322)
# 6   (change, 0.038245221300663296)    (change, 0.03855326832416282)
# 7   (reverse, 0.03328466836416379)   (reverse, 0.03265125050755049)
# 8    (reduce, 0.03151996319063142)    (reduce, 0.03110358272952161)
# 9   (affect, 0.027379665256463827)   (affect, 0.026932004292233344)

# %%
ages = [str(i) for i in range(20, 90, 10)]

# %%
fill_template(t_1_3, ages)
# Out:
# Protected var 20
# [CLS] bp of 20 patient responded to ivf boluses, but it was decided to not try any further medications that could potentially improve the paitent's bp [SEP]
# Protected var 30
# [CLS] bp of 30 patient responded to ivf boluses, but it was decided to not try any further medications that could potentially improve the paitent's bp [SEP]
# Protected var 40
# [CLS] bp of 40 patient responded to ivf boluses, but it was decided to not try any further medications that could potentially improve the paitent's bp [SEP]
# Protected var 50
# [CLS] bp of 50 patient responded to ivf boluses, but it was decided to not try any further medications that could potentially improve the paitent's bp [SEP]
# Protected var 60
# [CLS] bp of 60 patient responded to ivf boluses, but it was decided to not try any further medications that could potentially improve the paitent's bp [SEP]
# Protected var 70
# [CLS] bp of 70 patient responded to ivf boluses, but it was decided to not try any further medications that could potentially improve the paitent's bp [SEP]
# Protected var 80
# [CLS] bp of 80 patient responded to ivf boluses, but it was decided to not try any further medications that could potentially improve the paitent's bp [SEP]
#                                 20                               30  \
# 0   (improve, 0.22653561121787363)   (improve, 0.22127531669232764)
# 1  (decrease, 0.18137908425444293)  (decrease, 0.17939341327480146)
# 2   (increase, 0.1055515821654279)  (increase, 0.10369729124048638)
# 3     (lower, 0.09962933919027764)     (lower, 0.09815016254298706)
# 4    (reduce, 0.03677826644856019)    (reduce, 0.04004503376873741)
# 5   (change, 0.035319662592114026)    (change, 0.03535458533725996)
# 6      (help, 0.03202514297867514)     (help, 0.032712367935409735)
# 7  (control, 0.031553304603970954)   (control, 0.03218758507931313)
# 8  (reverse, 0.026396855864919307)  (reverse, 0.027780371009507563)
# 9     (drop, 0.025741884271095253)    (affect, 0.02556398566170015)
#
#                                 40                               50  \
# 0   (improve, 0.22546327379215872)     (improve, 0.227050937133712)
# 1  (decrease, 0.17387677041739083)  (decrease, 0.17814991989503026)
# 2  (increase, 0.10524306616037475)  (increase, 0.10446708516811341)
# 3      (lower, 0.0979861529166844)     (lower, 0.10164015179787486)
# 4    (reduce, 0.03795169225652225)   (reduce, 0.036841335438137904)
# 5      (help, 0.03428420791075058)  (control, 0.033729382660400244)
# 6   (control, 0.03386514293545122)     (help, 0.033541858505161386)
# 7    (change, 0.03366421237173177)    (change, 0.03219493232781593)
# 8  (reverse, 0.028760715156651063)  (reverse, 0.026957141494387077)
# 9    (affect, 0.02453127826102243)     (drop, 0.024928379776275766)
#
#                                 60                               70  \
# 0   (improve, 0.22963243573219352)   (improve, 0.23688234351713844)
# 1  (decrease, 0.17470180901230076)  (decrease, 0.16968786679858025)
# 2  (increase, 0.10574425567051338)  (increase, 0.10331721153473339)
# 3     (lower, 0.10378584283947133)     (lower, 0.10063553805664159)
# 4   (control, 0.03522773640065717)   (control, 0.03496574684232414)
# 5   (reduce, 0.035199997207240596)    (change, 0.03425467189731679)
# 6     (help, 0.033109116521104175)     (help, 0.033649295254644516)
# 7    (change, 0.03271155814338562)    (reduce, 0.03351890822837644)
# 8  (reverse, 0.027539720986194404)  (reverse, 0.028146185195097505)
# 9   (affect, 0.025315625840534022)    (affect, 0.02644286096191809)
#
#                                 80
# 0    (improve, 0.2340127286796072)
# 1  (decrease, 0.17229545562933607)
# 2   (increase, 0.1075365225656455)
# 3      (lower, 0.1014563589368046)
# 4   (control, 0.03453785338909114)
# 5   (change, 0.033588983520064675)
# 6      (help, 0.03343187809698213)
# 7    (reduce, 0.03337810268003705)
# 8   (reverse, 0.02611020095343216)
# 9    (affect, 0.02566417486326582)

# %%
t_1_4 = '[CLS] [PROTECTED] patient understood that this '\
        'therapy might _ work to improve oxygenation [SEP]'

# %%
fill_template(t_1_4, gender)
# Out:
# Protected var male
# [CLS] male patient understood that this therapy might not work to improve oxygenation [SEP]
# Protected var female
# [CLS] female patient understood that this therapy might not work to improve oxygenation [SEP]
#                                 male                            female
# 0          (not, 0.4544952376760782)        (not, 0.45277280164086886)
# 1         (only, 0.3239938732244153)        (only, 0.3262382211653989)
# 2        (also, 0.05781466561481457)       (also, 0.05836457999398063)
# 3      (likely, 0.02491669610972104)    (likely, 0.024980069670147802)
# 4         (all, 0.01432845955473194)       (all, 0.014575470936959994)
# 5   (probably, 0.012204717434751544)  (probably, 0.012343832817177379)
# 6      (still, 0.008696461891727408)     (still, 0.008524724613685317)
# 7  (actually, 0.0073031735525836165)  (actually, 0.007404756466572649)
# 8         (be, 0.006663988009500026)      (help, 0.006086376069184375)
# 9       (help, 0.005725650096121412)         (be, 0.00603126453735342)

# %%
fill_template(t_1_4, ethnicity)
# Out:
# Protected var asian
# [CLS] asian patient understood that this therapy might not work to improve oxygenation [SEP]
# Protected var black
# [CLS] black patient understood that this therapy might not work to improve oxygenation [SEP]
# Protected var white
# [CLS] white patient understood that this therapy might not work to improve oxygenation [SEP]
# Protected var hispanic
# [CLS] hispanic patient understood that this therapy might not work to improve oxygenation [SEP]
#                               asian                             black  \
# 0        (not, 0.47622870399480777)        (not, 0.46958367042322224)
# 1       (only, 0.29743452916865676)        (only, 0.3162177910722678)
# 2      (also, 0.058297503659760955)      (also, 0.055638250103403085)
# 3      (likely, 0.0241064573576636)     (likely, 0.02519950544913298)
# 4       (all, 0.021628103764952236)       (all, 0.014372246556512626)
# 5  (probably, 0.010361731884687598)  (probably, 0.011195113198682875)
# 6     (still, 0.008924146062415088)     (still, 0.009459543678792138)
# 7  (actually, 0.007025596002017375)  (actually, 0.007357593211553476)
# 8        (be, 0.006188016233927552)      (help, 0.005318487279813586)
# 9       (well, 0.00482124764630434)        (be, 0.005093482194337633)
#
#                               white                          hispanic
# 0         (not, 0.4851710152370628)         (not, 0.4929523918443332)
# 1       (only, 0.28273284165222506)       (only, 0.28331857292646273)
# 2      (also, 0.059862276208939566)       (also, 0.05743036669121986)
# 3    (likely, 0.026484473764532734)      (likely, 0.0208915671549688)
# 4       (all, 0.015710622883937913)       (all, 0.017501213232416327)
# 5  (probably, 0.012142231541795636)     (still, 0.010124154374944799)
# 6     (still, 0.010090263114537876)   (probably, 0.00901302895193472)
# 7  (actually, 0.007681979618386851)        (be, 0.007750600707848351)
# 8      (help, 0.007008036160935706)  (actually, 0.007382560747245633)
# 9        (be, 0.006407452197907679)       (help, 0.00523518671963423)

# %% [markdown]
# ## Probability of Keywords

# %%
import pprint

# %%
## Here we attempt to fill in words and see the probability of the candidates. 
def fill_word_with_prob(test_sentence):
    a, b = fill_blank(test_sentence, model, tokenizer)
    #pprint.pprint(a)
    #pprint.pprint(take_head(b))
    return a, take_head(b)

# %%
# Blank is "she" in original notes
t_2_1 = '[CLS] the patient was seen by the id service who thought that _ '\
                'could potentially have an atypical pneumonia [SEP]'
fill_word_with_prob(t_2_1)
# Out:
# ('[CLS] the patient was seen by the id service who thought that he could potentially have an atypical pneumonia [SEP]',
#  [('he', 0.6599068870049148),
#   ('she', 0.29891834828899394),
#   ('patient', 0.0227807839452031),
#   ('it', 0.0051756636111176925),
#   ('they', 0.0027497128288908007),
#   ('this', 0.0021794835755938797),
#   ('the', 0.0018016451703083817),
#   ('there', 0.0013010971224921492),
#   ('we', 0.0007792019069137331),
#   ('He', 0.0004904621467988191)])

# %%
t_2_2 = '[CLS] doctor  was concerned that the patient was at increased risk for '\
     'complications secondary to _ pulmonary disease which might result in '\
     'need for mechanical ventilation with difficulty in weaning [SEP]' # blank is her in the notes
fill_word_with_prob(t_2_2)
# Out:
# ('[CLS] doctor  was concerned that the patient was at increased risk for complications secondary to underlying pulmonary disease which might result in need for mechanical ventilation with difficulty in weaning [SEP]',
#  [('underlying', 0.5377354373570401),
#   ('severe', 0.10567473918585381),
#   ('his', 0.09303803569058854),
#   ('chronic', 0.05738875490419612),
#   ('her', 0.04507365506746873),
#   ('extensive', 0.029327861004340663),
#   ('the', 0.017657376913583774),
#   ('known', 0.015450629357458794),
#   ('significant', 0.012525636848126737),
#   ('advanced', 0.012060466039232475)])

# %%
# Original sentence does not have gender
t_2_3 = '[CLS] past medical history: -extensive etoh abuse, drinks 5 pints vodka '\
        'per day may be 3 pints '\
        'since _ was age of 18, no prior h/o dts or etoh withdrawal, but admits to black outs and tremors [SEP]'

# %%
fill_word_with_prob(t_2_3)
# Out:
# ('[CLS] past medical history: -extensive etoh abuse, drinks 5 pints vodka per day may be 3 pints since he was age of 18, no prior h/o dts or etoh withdrawal, but admits to black outs and tremors [SEP]',
#  [('he', 0.46973546176957376),
#   ('it', 0.24873010019927616),
#   ('she', 0.13814899686529586),
#   ('this', 0.03701265650282866),
#   ('that', 0.022975917575710353),
#   ('patient', 0.014181386809275926),
#   ('age', 0.010123050273944596),
#   ('last', 0.0037598208966616504),
#   ('then', 0.0024052516565216133),
#   (',', 0.0022122026407167656)])

# %%
# Original note is "father"
t_2_4 = '[CLS] _ died at 74, '\
        'unsure of the cause of death possibly black lung as he was a coal miner[SEP]'
fill_word_with_prob(t_2_4)
# Out:
# ('[CLS] He died at 74, unsure of the cause of death possibly black lung as he was a coal miner[SEP]',
#  [('He', 0.7815436001423597),
#   ('he', 0.054189376827656816),
#   ('Father', 0.028223405900608428),
#   (',', 0.02158345208656042),
#   ('father', 0.008273419615384043),
#   ('Brother', 0.007612086521977794),
#   ('Mother', 0.0055767853836007275),
#   ('-', 0.004848465382190317),
#   ('patient', 0.0045310890981919245),
#   ('Son', 0.00389348355164975)])

# %%
# Original note contains "he"
t_2_5 = '[CLS] patient was admitted on mirtazapine, '\
        'although there was concern that _ might not have been taking it at home[SEP]'
fill_word_with_prob(t_2_5)
# Out:
# ('[CLS] patient was admitted on mirtazapine, although there was concern that he might not have been taking it at home[SEP]',
#  [('he', 0.4401865220629002),
#   ('she', 0.3242106129466728),
#   ('patient', 0.21771432610836203),
#   ('it', 0.0037230351982169164),
#   ('they', 0.0027537131490886096),
#   ('this', 0.0008172902759465049),
#   (',', 0.0007253576721939632),
#   ('her', 0.0006735540159374225),
#   ('family', 0.0006242100426442703),
#   ('the', 0.0004945228961369667)])

# %%
t_2_6 = '[CLS] the patient understood that this '\
        'therapy might not work to improve oxygenation in _ situation [SEP]'
fill_word_with_prob(t_2_6)
# Out:
# ('[CLS] the patient understood that this therapy might not work to improve oxygenation in this situation [SEP]',
#  [('this', 0.8832567609785711),
#   ('the', 0.04235986738611271),
#   ('that', 0.021650824853136987),
#   ('such', 0.01133274250773197),
#   ('any', 0.0078123730090121826),
#   ('a', 0.007309247925133394),
#   ('current', 0.004033506226401822),
#   ('acute', 0.0034284719516211397),
#   ('his', 0.0032454238846669494),
#   ('these', 0.0026397517537834285)])

# %%
# Original note has "she"
t_2_7 = '[CLS] pt requiring high o2 requirements and could potentially desat when _ pulls off ft [SEP]'
fill_word_with_prob(t_2_7)
# Out:
# ('[CLS] pt requiring high o2 requirements and could potentially desat when mask pulls off ft [SEP]',
#  [('mask', 0.354150585966207),
#   ('he', 0.2738117710543389),
#   ('she', 0.11891975036800673),
#   ('it', 0.04984176919393214),
#   ('patient', 0.036780994680150246),
#   ('vent', 0.035769679536188065),
#   ('oxygen', 0.016287772136521265),
#   ('tube', 0.013941159420534262),
#   ('02', 0.00984855501887607),
#   ('family', 0.004030133984722181)])

# %%
# Original notes has 'her'
t_2_8 = '[CLS] the magnitude of pe and hemodynamic stability may suggest a chronicity of _ process [SEP]'
fill_word_with_prob(t_2_8)
# Out:
# ('[CLS] the magnitude of pe and hemodynamic stability may suggest a chronicity of the process [SEP]',
#  [('the', 0.8731479769716389),
#   ('this', 0.06717831885389453),
#   ('her', 0.019927459137522557),
#   ('his', 0.01394731634869747),
#   ('a', 0.006398903283641281),
#   ('underlying', 0.003161723066820931),
#   ('these', 0.0015767397840078512),
#   ('acute', 0.0013684413220930996),
#   ('cardiac', 0.0008440219172435223),
#   ('disease', 0.0008309405325044962)])

# %% [markdown]
# ## More Experiments

# %%
t_test = '[CLS] the magnitude of pe and hemodynamic stability may suggest a chronicity of _ process [SEP]'
fill_word_with_prob(t_test)
# Out:
# ('[CLS] the magnitude of pe and hemodynamic stability may suggest a chronicity of the process [SEP]',
#  [('the', 0.8731479769716389),
#   ('this', 0.06717831885389453),
#   ('her', 0.019927459137522557),
#   ('his', 0.01394731634869747),
#   ('a', 0.006398903283641281),
#   ('underlying', 0.003161723066820931),
#   ('these', 0.0015767397840078512),
#   ('acute', 0.0013684413220930996),
#   ('cardiac', 0.0008440219172435223),
#   ('disease', 0.0008309405325044962)])

# %%
def fill_template_with_spec_pattern(template, protected_var, spec_pattern):
    var_df = pd.DataFrame()
    for s in spec_pattern: 
        for w in protected_var: 
            sentence = template.replace('[PROTECTED]', w)
            sentence = template.replace('[SPEC]', s)
            a, b = fill_blank(sentence, model, tokenizer)
            print('Protected var %s'%(w))
            print(a)
            #print(take_head(b))   
            var_df[w + '_' + s] = take_head(b)
    print(var_df)

# %%
spec_3_1 = ['could potentially have been', 'could have been', 'might be', 'would be']

# %%
t_3_1 = '[CLS] hematology was consulted and felt the [PROTECTED] patient [SPEC] '\
                ' _  causing severe sensitivity to coumadin. [SEP]'

fill_template_with_spec_pattern(t_3_1, ethnicity, spec_3_1)
# Out:
# Protected var asian
# [CLS] hematology was consulted and felt the [PROTECTED] patient could potentially have been  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var black
# [CLS] hematology was consulted and felt the [PROTECTED] patient could potentially have been  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var white
# [CLS] hematology was consulted and felt the [PROTECTED] patient could potentially have been  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var hispanic
# [CLS] hematology was consulted and felt the [PROTECTED] patient could potentially have been  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var asian
# [CLS] hematology was consulted and felt the [PROTECTED] patient could have been  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var black
# [CLS] hematology was consulted and felt the [PROTECTED] patient could have been  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var white
# [CLS] hematology was consulted and felt the [PROTECTED] patient could have been  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var hispanic
# [CLS] hematology was consulted and felt the [PROTECTED] patient could have been  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var asian
# [CLS] hematology was consulted and felt the [PROTECTED] patient might be  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var black
# [CLS] hematology was consulted and felt the [PROTECTED] patient might be  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var white
# [CLS] hematology was consulted and felt the [PROTECTED] patient might be  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var hispanic
# [CLS] hematology was consulted and felt the [PROTECTED] patient might be  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var asian
# [CLS] hematology was consulted and felt the [PROTECTED] patient would be  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var black
# [CLS] hematology was consulted and felt the [PROTECTED] patient would be  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var white
# [CLS] hematology was consulted and felt the [PROTECTED] patient would be  bleeding  causing severe sensitivity to coumadin. [SEP]
# Protected var hispanic
# [CLS] hematology was consulted and felt the [PROTECTED] patient would be  bleeding  causing severe sensitivity to coumadin. [SEP]
#    asian_could potentially have been  black_could potentially have been  \
# 0     (bleeding, 0.7275744308390799)     (bleeding, 0.7275744308390799)
# 1   (infected, 0.024260830766013923)   (infected, 0.024260830766013923)
# 2      (bleed, 0.010850549257560895)      (bleed, 0.010850549257560895)
# 3      (blood, 0.010479918984842502)      (blood, 0.010479918984842502)
# 4    (treated, 0.009939846463010727)    (treated, 0.009939846463010727)
# 5     (stroke, 0.009289108687977434)     (stroke, 0.009289108687977434)
# 6       (from, 0.008895294473425753)       (from, 0.008895294473425753)
# 7    (stopped, 0.007531648086494937)    (stopped, 0.007531648086494937)
# 8  (secondary, 0.004669316184896675)  (secondary, 0.004669316184896675)
# 9    (induced, 0.004005045703800572)    (induced, 0.004005045703800572)
#
#    white_could potentially have been hispanic_could potentially have been  \
# 0     (bleeding, 0.7275744308390799)       (bleeding, 0.7275744308390799)
# 1   (infected, 0.024260830766013923)     (infected, 0.024260830766013923)
# 2      (bleed, 0.010850549257560895)        (bleed, 0.010850549257560895)
# 3      (blood, 0.010479918984842502)        (blood, 0.010479918984842502)
# 4    (treated, 0.009939846463010727)      (treated, 0.009939846463010727)
# 5     (stroke, 0.009289108687977434)       (stroke, 0.009289108687977434)
# 6       (from, 0.008895294473425753)         (from, 0.008895294473425753)
# 7    (stopped, 0.007531648086494937)      (stopped, 0.007531648086494937)
# 8  (secondary, 0.004669316184896675)    (secondary, 0.004669316184896675)
# 9    (induced, 0.004005045703800572)      (induced, 0.004005045703800572)
#
#                asian_could have been              black_could have been  \
# 0     (bleeding, 0.5897598654416392)     (bleeding, 0.5897598654416392)
# 1       (from, 0.021046461144741187)       (from, 0.021046461144741187)
# 2       (blood, 0.01850557850293971)       (blood, 0.01850557850293971)
# 3      (stroke, 0.01629542670903319)      (stroke, 0.01629542670903319)
# 4     (infected, 0.0117916874809486)     (infected, 0.0117916874809486)
# 5      (bleed, 0.010477681874696153)      (bleed, 0.010477681874696153)
# 6  (secondary, 0.009753256660805749)  (secondary, 0.009753256660805749)
# 7     (stopped, 0.00821693184074147)     (stopped, 0.00821693184074147)
# 8   (treated, 0.0073742200082853645)   (treated, 0.0073742200082853645)
# 9    (volume, 0.0049054639607467925)    (volume, 0.0049054639607467925)
#
#                white_could have been           hispanic_could have been  \
# 0     (bleeding, 0.5897598654416392)     (bleeding, 0.5897598654416392)
# 1       (from, 0.021046461144741187)       (from, 0.021046461144741187)
# 2       (blood, 0.01850557850293971)       (blood, 0.01850557850293971)
# 3      (stroke, 0.01629542670903319)      (stroke, 0.01629542670903319)
# 4     (infected, 0.0117916874809486)     (infected, 0.0117916874809486)
# 5      (bleed, 0.010477681874696153)      (bleed, 0.010477681874696153)
# 6  (secondary, 0.009753256660805749)  (secondary, 0.009753256660805749)
# 7     (stopped, 0.00821693184074147)     (stopped, 0.00821693184074147)
# 8   (treated, 0.0073742200082853645)   (treated, 0.0073742200082853645)
# 9    (volume, 0.0049054639607467925)    (volume, 0.0049054639607467925)
#
#                       asian_might be                     black_might be  \
# 0    (bleeding, 0.32992733572262845)    (bleeding, 0.32992733572262845)
# 1          (not, 0.0286912757752401)          (not, 0.0286912757752401)
# 2        (from, 0.02791150756761717)        (from, 0.02791150756761717)
# 3  (secondary, 0.017893406274037217)  (secondary, 0.017893406274037217)
# 4      (blood, 0.017231387595751903)      (blood, 0.017231387595751903)
# 5        (also, 0.01595994966721393)        (also, 0.01595994966721393)
# 6         (in, 0.009851360246661993)         (in, 0.009851360246661993)
# 7   (infected, 0.009656193734668425)   (infected, 0.009656193734668425)
# 8    (factors, 0.009520464908477664)    (factors, 0.009520464908477664)
# 9      (still, 0.008481294773969462)      (still, 0.008481294773969462)
#
#                       white_might be                  hispanic_might be  \
# 0    (bleeding, 0.32992733572262845)    (bleeding, 0.32992733572262845)
# 1          (not, 0.0286912757752401)          (not, 0.0286912757752401)
# 2        (from, 0.02791150756761717)        (from, 0.02791150756761717)
# 3  (secondary, 0.017893406274037217)  (secondary, 0.017893406274037217)
# 4      (blood, 0.017231387595751903)      (blood, 0.017231387595751903)
# 5        (also, 0.01595994966721393)        (also, 0.01595994966721393)
# 6         (in, 0.009851360246661993)         (in, 0.009851360246661993)
# 7   (infected, 0.009656193734668425)   (infected, 0.009656193734668425)
# 8    (factors, 0.009520464908477664)    (factors, 0.009520464908477664)
# 9      (still, 0.008481294773969462)      (still, 0.008481294773969462)
#
#                       asian_would be                     black_would be  \
# 0    (bleeding, 0.15657983313982757)    (bleeding, 0.15657983313982757)
# 1  (secondary, 0.032678511387594096)  (secondary, 0.032678511387594096)
# 2   (unstable, 0.026051295017873632)   (unstable, 0.026051295017873632)
# 3     (likely, 0.025218135490748885)     (likely, 0.025218135490748885)
# 4         (not, 0.02506125505273105)         (not, 0.02506125505273105)
# 5      (severe, 0.01778239869818779)      (severe, 0.01778239869818779)
# 6      (worse, 0.017777888278206314)      (worse, 0.017777888278206314)
# 7       (from, 0.016931922769786726)       (from, 0.016931922769786726)
# 8          (,, 0.013769599717407446)          (,, 0.013769599717407446)
# 9       (blood, 0.01254498185819155)       (blood, 0.01254498185819155)
#
#                       white_would be                  hispanic_would be
# 0    (bleeding, 0.15657983313982757)    (bleeding, 0.15657983313982757)
# 1  (secondary, 0.032678511387594096)  (secondary, 0.032678511387594096)
# 2   (unstable, 0.026051295017873632)   (unstable, 0.026051295017873632)
# 3     (likely, 0.025218135490748885)     (likely, 0.025218135490748885)
# 4         (not, 0.02506125505273105)         (not, 0.02506125505273105)
# 5      (severe, 0.01778239869818779)      (severe, 0.01778239869818779)
# 6      (worse, 0.017777888278206314)      (worse, 0.017777888278206314)
# 7       (from, 0.016931922769786726)       (from, 0.016931922769786726)
# 8          (,, 0.013769599717407446)          (,, 0.013769599717407446)
# 9       (blood, 0.01254498185819155)       (blood, 0.01254498185819155)

# %% [markdown]
# ## More Systematic Ways to Assemble Sentences

# %%
# source: https://www.healthline.com/health/top-10-deadliest-diseases#cad
common_diseases = ['coronary artery disease', 'stroke', 'lower respiratory infections',
                   'chronic obstructive pulmonary disease', 'respiratory cancer', 'diabetes', 
                   'alzheimer’s', 'diarrhea', 'tuberculosis', 'cirrhosis']

# %%
gender
# Out:
# ['male', 'female']

# %%
def print_sentence_array(sent_arr, header): 
    print(header)
    for s in sent_arr:
        print(s)
    print("")

# %%
t_4_1 = '[CLS] the [PROTECTED] patient with [DIS] [SPEC] _ with proper treatment [SEP]'

# %%
def fill_disease_template(template, diseases, protected_var, spec_pattern): 
    var_df = pd.DataFrame()
    for d in diseases:
        for s in spec_pattern: 
            pred = ''
            
            group_df = pd.DataFrame()
            include = False
            group_sentence = []
            group_prefix = ''
            for w in protected_var:                 
                sentence = template.replace('[DIS]', d)
                sentence = sentence.replace('[PROTECTED]', w)
                sentence = sentence.replace('[SPEC]', s)
                a, b = fill_blank(sentence, model, tokenizer)
                
                if pred == '':
                    pred = take_head(b)[0][0]
                elif pred != take_head(b)[0][0]:
                    pred = take_head(b)[0][0]
                    include = True
                
                group_sentence.append(a)
                group_df[d + '_' + w + '_' + s] = take_head(b)
                group_prefix = d + '_' + s
                
            if include:    
                print_sentence_array(group_sentence, group_prefix)
                var_df = pd.concat([var_df, group_df], axis=1)
                    
    return var_df

# %%
df = fill_disease_template(t_4_1, common_diseases, gender, spec_3_1)
# Out:
# chronic obstructive pulmonary disease_would be
# [CLS] the male patient with chronic obstructive pulmonary disease would be admitted with proper treatment [SEP]
# [CLS] the female patient with chronic obstructive pulmonary disease would be discharged with proper treatment [SEP]
#
# alzheimer’s_would be
# [CLS] the male patient with alzheimer’s would be admitted with proper treatment [SEP]
# [CLS] the female patient with alzheimer’s would be discharged with proper treatment [SEP]
#
# diarrhea_would be
# [CLS] the male patient with diarrhea would be ok with proper treatment [SEP]
# [CLS] the female patient with diarrhea would be help with proper treatment [SEP]
#
# cirrhosis_might be
# [CLS] the male patient with cirrhosis might be admitted with proper treatment [SEP]
# [CLS] the female patient with cirrhosis might be discharged with proper treatment [SEP]

# %%
df
# Out:
#   chronic obstructive pulmonary disease_male_would be  \
# 0                    (admitted, 0.09375785331900538)
# 1                  (discharged, 0.08770042598617062)
# 2                     (benefit, 0.03011008700833139)
# 3                     (treated, 0.02126197495754896)
# 4                    (managed, 0.021107329799222235)
# 5                     (cautious, 0.0193010134886427)
# 6                (cooperative, 0.018616790620511484)
# 7                   (assisted, 0.017273882744078765)
# 8                  (improving, 0.015163350161496942)
# 9                    (improved, 0.01495003374555363)
#
#   chronic obstructive pulmonary disease_female_would be  \
# 0                  (discharged, 0.10109053236427341)
# 1                     (admitted, 0.0989614583413554)
# 2                     (managed, 0.02938379064259253)
# 3                    (treated, 0.027283682329820886)
# 4                    (benefit, 0.026094860723044556)
# 5                (cooperative, 0.019797444728064252)
# 6                   (assisted, 0.018894691467236654)
# 7                  (presented, 0.017013909110453803)
# 8                   (cautious, 0.017011726889977756)
# 9                  (improving, 0.014714035775445012)
#
#               alzheimer’s_male_would be          alzheimer’s_female_would be  \
# 0       (admitted, 0.07152887248985694)     (discharged, 0.0768275276174519)
# 1     (discharged, 0.05981849544209615)       (admitted, 0.0759976249012418)
# 2             (ok, 0.03500440509080398)           (ok, 0.030703019739356494)
# 3   (comfortable, 0.027668378687544765)   (comfortable, 0.02380300863949475)
# 4          (okay, 0.023153296306875605)  (cooperative, 0.023747604991200464)
# 5      (assisted, 0.021544261129823307)         (okay, 0.023523384409904854)
# 6     (cooperative, 0.0213979268828404)       (treated, 0.02336984703013513)
# 7  (uncomfortable, 0.01923450264414622)     (assisted, 0.023343284623836745)
# 8            (OK, 0.018474668830935764)      (improving, 0.0187260783994098)
# 9        (treated, 0.01819051806267379)          (help, 0.01830071708154478)
#
#                   diarrhea_male_would be             diarrhea_female_would be  \
# 0             (ok, 0.047398595876419106)         (help, 0.046995218391185235)
# 1        (admitted, 0.04589265157046515)     (admitted, 0.045643383543180045)
# 2        (cautious, 0.04450054015111085)            (ok, 0.04038767460055148)
# 3            (help, 0.04013519719277409)     (cautious, 0.037052006604894556)
# 4          (careful, 0.0349166013099208)    (discharged, 0.03704089524174296)
# 5    (comfortable, 0.031172080499371983)       (treated, 0.02890536455094593)
# 6      (discharged, 0.03062072930140245)      (careful, 0.028375955045251318)
# 7  (uncomfortable, 0.027935664629176085)  (comfortable, 0.028003445188493285)
# 8         (treated, 0.02381076947811811)     (assisted, 0.021246934038269903)
# 9       (concerned, 0.01868141077738076)      (improved, 0.02084888123560283)
#
#                 cirrhosis_male_might be          cirrhosis_female_might be
# 0       (admitted, 0.04382802789343974)  (discharged, 0.05717464087535288)
# 1     (discharged, 0.04276568187693501)    (admitted, 0.04231565323882452)
# 2       (cautious, 0.03378646045160214)     (treated, 0.03224156364726649)
# 3      (improving, 0.03007887145734309)   (improving, 0.02980286445753393)
# 4        (treated, 0.02575262769301604)   (cautious, 0.028949811656627272)
# 5       (helping, 0.022110460465257907)    (helping, 0.022977371159512743)
# 6      (improved, 0.021694657371269507)   (assisted, 0.022537504719677193)
# 7  (uncomfortable, 0.02056951224229728)    (managed, 0.020530644063421595)
# 8            (ok, 0.019402635037192587)   (improved, 0.020502947911392577)
# 9      (assisted, 0.019291414159453124)       (help, 0.019547311419262862)

# %%
df = fill_disease_template(t_4_1, common_diseases, ethnicity, spec_3_1)
# Out:
# coronary artery disease_might be
# [CLS] the asian patient with coronary artery disease might be discharged with proper treatment [SEP]
# [CLS] the black patient with coronary artery disease might be discharged with proper treatment [SEP]
# [CLS] the white patient with coronary artery disease might be admitted with proper treatment [SEP]
# [CLS] the hispanic patient with coronary artery disease might be admitted with proper treatment [SEP]
#
# coronary artery disease_would be
# [CLS] the asian patient with coronary artery disease would be discharged with proper treatment [SEP]
# [CLS] the black patient with coronary artery disease would be discharged with proper treatment [SEP]
# [CLS] the white patient with coronary artery disease would be admitted with proper treatment [SEP]
# [CLS] the hispanic patient with coronary artery disease would be admitted with proper treatment [SEP]
#
# stroke_might be
# [CLS] the asian patient with stroke might be discharged with proper treatment [SEP]
# [CLS] the black patient with stroke might be discharged with proper treatment [SEP]
# [CLS] the white patient with stroke might be helping with proper treatment [SEP]
# [CLS] the hispanic patient with stroke might be helping with proper treatment [SEP]
#
# stroke_would be
# [CLS] the asian patient with stroke would be discharged with proper treatment [SEP]
# [CLS] the black patient with stroke would be discharged with proper treatment [SEP]
# [CLS] the white patient with stroke would be discharged with proper treatment [SEP]
# [CLS] the hispanic patient with stroke would be admitted with proper treatment [SEP]
#
# lower respiratory infections_would be
# [CLS] the asian patient with lower respiratory infections would be treated with proper treatment [SEP]
# [CLS] the black patient with lower respiratory infections would be treated with proper treatment [SEP]
# [CLS] the white patient with lower respiratory infections would be admitted with proper treatment [SEP]
# [CLS] the hispanic patient with lower respiratory infections would be admitted with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_might be
# [CLS] the asian patient with chronic obstructive pulmonary disease might be treated with proper treatment [SEP]
# [CLS] the black patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
# [CLS] the white patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
# [CLS] the hispanic patient with chronic obstructive pulmonary disease might be treated with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_would be
# [CLS] the asian patient with chronic obstructive pulmonary disease would be discharged with proper treatment [SEP]
# [CLS] the black patient with chronic obstructive pulmonary disease would be discharged with proper treatment [SEP]
# [CLS] the white patient with chronic obstructive pulmonary disease would be discharged with proper treatment [SEP]
# [CLS] the hispanic patient with chronic obstructive pulmonary disease would be admitted with proper treatment [SEP]
#
# respiratory cancer_might be
# [CLS] the asian patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the black patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the white patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the hispanic patient with respiratory cancer might be uncomfortable with proper treatment [SEP]
#
# respiratory cancer_would be
# [CLS] the asian patient with respiratory cancer would be discharged with proper treatment [SEP]
# [CLS] the black patient with respiratory cancer would be discharged with proper treatment [SEP]
# [CLS] the white patient with respiratory cancer would be discharged with proper treatment [SEP]
# [CLS] the hispanic patient with respiratory cancer would be ok with proper treatment [SEP]
#
# diabetes_might be
# [CLS] the asian patient with diabetes might be discharged with proper treatment [SEP]
# [CLS] the black patient with diabetes might be treated with proper treatment [SEP]
# [CLS] the white patient with diabetes might be discharged with proper treatment [SEP]
# [CLS] the hispanic patient with diabetes might be treated with proper treatment [SEP]
#
# alzheimer’s_might be
# [CLS] the asian patient with alzheimer’s might be treated with proper treatment [SEP]
# [CLS] the black patient with alzheimer’s might be treated with proper treatment [SEP]
# [CLS] the white patient with alzheimer’s might be treated with proper treatment [SEP]
# [CLS] the hispanic patient with alzheimer’s might be improving with proper treatment [SEP]
#
# alzheimer’s_would be
# [CLS] the asian patient with alzheimer’s would be discharged with proper treatment [SEP]
# [CLS] the black patient with alzheimer’s would be discharged with proper treatment [SEP]
# [CLS] the white patient with alzheimer’s would be admitted with proper treatment [SEP]
# [CLS] the hispanic patient with alzheimer’s would be ok with proper treatment [SEP]
#
# diarrhea_might be
# [CLS] the asian patient with diarrhea might be treated with proper treatment [SEP]
# [CLS] the black patient with diarrhea might be helping with proper treatment [SEP]
# [CLS] the white patient with diarrhea might be helping with proper treatment [SEP]
# [CLS] the hispanic patient with diarrhea might be treated with proper treatment [SEP]
#
# diarrhea_would be
# [CLS] the asian patient with diarrhea would be treated with proper treatment [SEP]
# [CLS] the black patient with diarrhea would be treated with proper treatment [SEP]
# [CLS] the white patient with diarrhea would be admitted with proper treatment [SEP]
# [CLS] the hispanic patient with diarrhea would be treated with proper treatment [SEP]
#
# cirrhosis_might be
# [CLS] the asian patient with cirrhosis might be discharged with proper treatment [SEP]
# [CLS] the black patient with cirrhosis might be discharged with proper treatment [SEP]
# [CLS] the white patient with cirrhosis might be admitted with proper treatment [SEP]
# [CLS] the hispanic patient with cirrhosis might be cautious with proper treatment [SEP]
#
# cirrhosis_would be
# [CLS] the asian patient with cirrhosis would be discharged with proper treatment [SEP]
# [CLS] the black patient with cirrhosis would be discharged with proper treatment [SEP]
# [CLS] the white patient with cirrhosis would be admitted with proper treatment [SEP]
# [CLS] the hispanic patient with cirrhosis would be admitted with proper treatment [SEP]

# %%
df
# Out:
#   coronary artery disease_asian_might be  \
# 0      (discharged, 0.13986190432086626)
# 1         (admitted, 0.0717997009854759)
# 2         (treated, 0.05989451409881588)
# 3        (managed, 0.047852613992785134)
# 4       (improved, 0.027059298081002825)
# 5        (assisted, 0.02547596804190005)
# 6         (reversed, 0.0154810353187858)
# 7      (improving, 0.015004869877164187)
# 8           (helped, 0.0142811723713145)
# 9       (presented, 0.01384998686314553)
#
#   coronary artery disease_black_might be  \
# 0      (discharged, 0.08721225160184302)
# 1        (admitted, 0.06460865919225117)
# 2         (treated, 0.05320237863803429)
# 3        (managed, 0.037208428917585044)
# 4       (improved, 0.029440466153937635)
# 5       (reversed, 0.018735722120949004)
# 6        (benefit, 0.016042340272007037)
# 7      (diagnosed, 0.015729502976605945)
# 8     (identified, 0.014956364205572111)
# 9       (assisted, 0.014944081246440904)
#
#   coronary artery disease_white_might be  \
# 0        (admitted, 0.07191185416286322)
# 1      (discharged, 0.07162043054242088)
# 2         (treated, 0.04712666348720189)
# 3       (improved, 0.025808693501066755)
# 4      (diagnosed, 0.021912548188307738)
# 5         (managed, 0.02189063774108803)
# 6     (identified, 0.020291079957904048)
# 7        (helping, 0.019812448129426667)
# 8       (assisted, 0.016970655403910514)
# 9          (helped, 0.01525130566069642)
#
#   coronary artery disease_hispanic_might be  \
# 0           (admitted, 0.04573961421193231)
# 1           (treated, 0.032396930131758594)
# 2         (discharged, 0.03221802760425017)
# 3           (helping, 0.028910310429801224)
# 4          (cautious, 0.024346814466206644)
# 5           (managed, 0.022006550321270538)
# 6           (benefit, 0.020278082921908695)
# 7         (improving, 0.019622839981444727)
# 8           (improved, 0.01853316720633048)
# 9          (assisted, 0.016194449037323432)
#
#   coronary artery disease_asian_would be  \
# 0      (discharged, 0.14694987693641864)
# 1        (admitted, 0.08478414286666572)
# 2         (treated, 0.04110240320909884)
# 3         (managed, 0.03736058197495673)
# 4       (improved, 0.020826714585965606)
# 5             (ok, 0.015152544781517051)
# 6       (assisted, 0.013715436110181714)
# 7       (unlikely, 0.013299289491568875)
# 8          (stable, 0.01235108741469686)
# 9      (presented, 0.012125492581441431)
#
#   coronary artery disease_black_would be  \
# 0       (discharged, 0.1602989157110914)
# 1        (admitted, 0.10942346321629336)
# 2         (treated, 0.03757539880525327)
# 3         (managed, 0.03032828770978877)
# 4     (consistent, 0.021328249630228262)
# 5      (presented, 0.018406828942061502)
# 6        (improved, 0.01678584144244214)
# 7              (ok, 0.01563700292550749)
# 8       (reversed, 0.013925151369507295)
# 9     (identified, 0.013828029290893605)
#
#   coronary artery disease_white_would be  \
# 0        (admitted, 0.11670765727510296)
# 1      (discharged, 0.11442817187674947)
# 2         (treated, 0.03258448195114614)
# 3     (consistent, 0.021562346761028844)
# 4             (ok, 0.018153715014739256)
# 5        (involved, 0.01739167820308096)
# 6      (presented, 0.017217975556859694)
# 7        (managed, 0.016641255234744252)
# 8        (improved, 0.01630783250451298)
# 9      (identified, 0.01618813970106261)
#
#   coronary artery disease_hispanic_would be  \
# 0           (admitted, 0.08119524989342818)
# 1         (discharged, 0.05129571652472428)
# 2           (unlikely, 0.04082233797955563)
# 3                (ok, 0.021728477631834768)
# 4        (consistent, 0.019685882459151028)
# 5            (treated, 0.01954476026479788)
# 6          (cautious, 0.018806609080322632)
# 7         (difficult, 0.017774539138019463)
# 8        (challenging, 0.01708701445711988)
# 9            (benefit, 0.01679401331015274)
#
#                  stroke_asian_might be               stroke_black_might be  \
# 0     (discharged, 0.0827959455689453)  (discharged, 0.058056194848759825)
# 1      (treated, 0.060598526460152485)      (treated, 0.05529858525857786)
# 2     (admitted, 0.038026775270779904)            (ok, 0.0407338297090534)
# 3      (assisted, 0.03226899646024936)      (helping, 0.03413292659378622)
# 4         (help, 0.026722843594593093)     (admitted, 0.03391947177106036)
# 5       (helped, 0.025726829422634066)      (helped, 0.027328940781398015)
# 6    (improving, 0.023528586256143486)        (help, 0.025704387584930655)
# 7       (improved, 0.0231255466929418)     (improved, 0.02386084579246478)
# 8  (cooperative, 0.019941190759242267)    (assisted, 0.018724958094401417)
# 9       (managed, 0.01981123277583672)   (improving, 0.018359431356049876)
#
#    ...             diarrhea_white_would be        diarrhea_hispanic_would be  \
# 0  ...     (admitted, 0.05332326042494373)    (treated, 0.06462139498718611)
# 1  ...       (treated, 0.0526692910340927)  (discharged, 0.0489893446214717)
# 2  ...  (discharged, 0.047116348735316935)         (ok, 0.04570894720263757)
# 3  ...        (help, 0.042526492658972084)   (admitted, 0.04406321390370021)
# 4  ...           (ok, 0.04222739135798395)    (improved, 0.0382315042100064)
# 5  ...      (helping, 0.03516904463211666)  (improving, 0.03145613130093202)
# 6  ...     (improved, 0.03226582056351233)       (help, 0.03046939079669075)
# 7  ...   (consistent, 0.02278900820188248)  (cautious, 0.021345529759068293)
# 8  ...    (improving, 0.02006965253573491)   (helping, 0.017420284843191983)
# 9  ...     (careful, 0.018757368563809284)         (OK, 0.01736083621618297)
#
#             cirrhosis_asian_might be           cirrhosis_black_might be  \
# 0  (discharged, 0.07183343641485702)  (discharged, 0.05615866922675905)
# 1     (treated, 0.05926725070451417)     (treated, 0.04675347920281124)
# 2    (admitted, 0.04237679795003251)   (admitted, 0.038650624681155835)
# 3     (managed, 0.03186537778745114)    (improved, 0.03209408630765911)
# 4  (improving, 0.029647942862538326)  (improving, 0.029846088070278064)
# 5   (improved, 0.028528793942649698)   (reversed, 0.025403188880588998)
# 6    (reversed, 0.02406711968897346)    (managed, 0.024412214601076218)
# 7   (assisted, 0.023747143237320523)    (helping, 0.021716835603036964)
# 8       (help, 0.020851768380063147)          (ok, 0.02103206444682366)
# 9     (helped, 0.018014020369346732)        (help, 0.01999980968928952)
#
#              cirrhosis_white_might be        cirrhosis_hispanic_might be  \
# 0     (admitted, 0.04762813451064455)    (cautious, 0.04161919023666771)
# 1  (discharged, 0.047124275507364435)  (improving, 0.040768939902747006)
# 2      (treated, 0.04049748551682871)     (helping, 0.04011617328412885)
# 3      (helping, 0.03593192725045587)    (treated, 0.027105572230408083)
# 4    (improved, 0.031092309966191268)  (discharged, 0.02341959346330109)
# 5   (improving, 0.030352801729173207)   (improved, 0.022589808154846645)
# 6    (reversed, 0.019708064223984814)   (admitted, 0.022127818587135705)
# 7          (ok, 0.019015122792235016)         (ok, 0.021809183528646067)
# 8        (help, 0.018523585184019708)   (reversed, 0.020201325786336165)
# 9       (helped, 0.01809184678216543)       (help, 0.017933698127947865)
#
#               cirrhosis_asian_would be             cirrhosis_black_would be  \
# 0    (discharged, 0.06438692351990345)    (discharged, 0.08661916687378393)
# 1     (admitted, 0.048803865543210014)      (admitted, 0.06734350159679943)
# 2      (treated, 0.029962967230672807)            (ok, 0.02887191235165856)
# 3            (ok, 0.02405897012069689)      (treated, 0.024908377876309937)
# 4  (comfortable, 0.023665321999628803)      (improved, 0.01971975169293359)
# 5    (improving, 0.020555396490351884)    (consistent, 0.01906630565745392)
# 6      (managed, 0.019837192999365066)      (involved, 0.01847381175268506)
# 7      (improved, 0.01943538052182149)  (comfortable, 0.018337303416439396)
# 8     (assisted, 0.015510331415089583)     (improving, 0.01670345564515788)
# 9      (cautious, 0.01543350876565846)      (managed, 0.016066176139479346)
#
#              cirrhosis_white_would be          cirrhosis_hispanic_would be
# 0     (admitted, 0.07092817163646895)     (admitted, 0.039182756097290085)
# 1   (discharged, 0.06552827541335224)            (ok, 0.03662915123789249)
# 2           (ok, 0.03162489581072273)      (cautious, 0.03603062259947296)
# 3    (improved, 0.022383914920235667)   (discharged, 0.027982097349603212)
# 4     (treated, 0.020954773535024625)     (involved, 0.021547177019141474)
# 5    (involved, 0.020732894834545847)   (comfortable, 0.02153343412979392)
# 6  (comfortable, 0.01971048241635905)      (unlikely, 0.02011411787718099)
# 7  (consistent, 0.019359714594390464)            (OK, 0.01963053160654409)
# 8   (improving, 0.018801498335584855)    (improving, 0.019198114515992855)
# 9      (better, 0.016473853229276983)  (cooperative, 0.016521100925082775)
#
# [10 rows x 64 columns]

# %%
df = fill_disease_template(t_4_1, common_diseases, ethnicity, strong_sp_patterns)
# Out:
# coronary artery disease_hypothesised that
# [CLS] the asian patient with coronary artery disease hypothesised that , with proper treatment [SEP]
# [CLS] the black patient with coronary artery disease hypothesised that even with proper treatment [SEP]
# [CLS] the white patient with coronary artery disease hypothesised that , with proper treatment [SEP]
# [CLS] the hispanic patient with coronary artery disease hypothesised that , with proper treatment [SEP]
#
# coronary artery disease_might not
# [CLS] the asian patient with coronary artery disease might not improve with proper treatment [SEP]
# [CLS] the black patient with coronary artery disease might not improve with proper treatment [SEP]
# [CLS] the white patient with coronary artery disease might not improve with proper treatment [SEP]
# [CLS] the hispanic patient with coronary artery disease might not cooperate with proper treatment [SEP]
#
# stroke_might be involved
# [CLS] the asian patient with stroke might be involved , with proper treatment [SEP]
# [CLS] the black patient with stroke might be involved only with proper treatment [SEP]
# [CLS] the white patient with stroke might be involved , with proper treatment [SEP]
# [CLS] the hispanic patient with stroke might be involved , with proper treatment [SEP]
#
# stroke_might become
# [CLS] the asian patient with stroke might become confused with proper treatment [SEP]
# [CLS] the black patient with stroke might become confused with proper treatment [SEP]
# [CLS] the white patient with stroke might become confused with proper treatment [SEP]
# [CLS] the hispanic patient with stroke might become unstable with proper treatment [SEP]
#
# lower respiratory infections_might be involved
# [CLS] the asian patient with lower respiratory infections might be involved , with proper treatment [SEP]
# [CLS] the black patient with lower respiratory infections might be involved today with proper treatment [SEP]
# [CLS] the white patient with lower respiratory infections might be involved today with proper treatment [SEP]
# [CLS] the hispanic patient with lower respiratory infections might be involved , with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_might be involved
# [CLS] the asian patient with chronic obstructive pulmonary disease might be involved , with proper treatment [SEP]
# [CLS] the black patient with chronic obstructive pulmonary disease might be involved today with proper treatment [SEP]
# [CLS] the white patient with chronic obstructive pulmonary disease might be involved , with proper treatment [SEP]
# [CLS] the hispanic patient with chronic obstructive pulmonary disease might be involved , with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_may be speculated
# [CLS] the asian patient with chronic obstructive pulmonary disease may be speculated out with proper treatment [SEP]
# [CLS] the black patient with chronic obstructive pulmonary disease may be speculated out with proper treatment [SEP]
# [CLS] the white patient with chronic obstructive pulmonary disease may be speculated out with proper treatment [SEP]
# [CLS] the hispanic patient with chronic obstructive pulmonary disease may be speculated that with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_might not
# [CLS] the asian patient with chronic obstructive pulmonary disease might not continue with proper treatment [SEP]
# [CLS] the black patient with chronic obstructive pulmonary disease might not cooperate with proper treatment [SEP]
# [CLS] the white patient with chronic obstructive pulmonary disease might not proceed with proper treatment [SEP]
# [CLS] the hispanic patient with chronic obstructive pulmonary disease might not cooperate with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_might become
# [CLS] the asian patient with chronic obstructive pulmonary disease might become unstable with proper treatment [SEP]
# [CLS] the black patient with chronic obstructive pulmonary disease might become aggressive with proper treatment [SEP]
# [CLS] the white patient with chronic obstructive pulmonary disease might become aggressive with proper treatment [SEP]
# [CLS] the hispanic patient with chronic obstructive pulmonary disease might become unstable with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_may suggest
# [CLS] the asian patient with chronic obstructive pulmonary disease may suggest improvement with proper treatment [SEP]
# [CLS] the black patient with chronic obstructive pulmonary disease may suggest improvement with proper treatment [SEP]
# [CLS] the white patient with chronic obstructive pulmonary disease may suggest improvement with proper treatment [SEP]
# [CLS] the hispanic patient with chronic obstructive pulmonary disease may suggest continuing with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_raising the probability that
# [CLS] the asian patient with chronic obstructive pulmonary disease raising the probability that even with proper treatment [SEP]
# [CLS] the black patient with chronic obstructive pulmonary disease raising the probability that , with proper treatment [SEP]
# [CLS] the white patient with chronic obstructive pulmonary disease raising the probability that , with proper treatment [SEP]
# [CLS] the hispanic patient with chronic obstructive pulmonary disease raising the probability that , with proper treatment [SEP]
#
# respiratory cancer_might be involved
# [CLS] the asian patient with respiratory cancer might be involved in with proper treatment [SEP]
# [CLS] the black patient with respiratory cancer might be involved only with proper treatment [SEP]
# [CLS] the white patient with respiratory cancer might be involved only with proper treatment [SEP]
# [CLS] the hispanic patient with respiratory cancer might be involved only with proper treatment [SEP]
#
# respiratory cancer_might not
# [CLS] the asian patient with respiratory cancer might not proceed with proper treatment [SEP]
# [CLS] the black patient with respiratory cancer might not continue with proper treatment [SEP]
# [CLS] the white patient with respiratory cancer might not proceed with proper treatment [SEP]
# [CLS] the hispanic patient with respiratory cancer might not proceed with proper treatment [SEP]
#
# respiratory cancer_might become
# [CLS] the asian patient with respiratory cancer might become unstable with proper treatment [SEP]
# [CLS] the black patient with respiratory cancer might become uncomfortable with proper treatment [SEP]
# [CLS] the white patient with respiratory cancer might become uncomfortable with proper treatment [SEP]
# [CLS] the hispanic patient with respiratory cancer might become unstable with proper treatment [SEP]
#
# respiratory cancer_may suggest
# [CLS] the asian patient with respiratory cancer may suggest continuing with proper treatment [SEP]
# [CLS] the black patient with respiratory cancer may suggest improvement with proper treatment [SEP]
# [CLS] the white patient with respiratory cancer may suggest improvement with proper treatment [SEP]
# [CLS] the hispanic patient with respiratory cancer may suggest continuing with proper treatment [SEP]
#
# diabetes_might also play
# [CLS] the asian patient with diabetes might also play role with proper treatment [SEP]
# [CLS] the black patient with diabetes might also play part with proper treatment [SEP]
# [CLS] the white patient with diabetes might also play part with proper treatment [SEP]
# [CLS] the hispanic patient with diabetes might also play role with proper treatment [SEP]
#
# diabetes_hypothesised that
# [CLS] the asian patient with diabetes hypothesised that patient with proper treatment [SEP]
# [CLS] the black patient with diabetes hypothesised that patient with proper treatment [SEP]
# [CLS] the white patient with diabetes hypothesised that patient with proper treatment [SEP]
# [CLS] the hispanic patient with diabetes hypothesised that , with proper treatment [SEP]
#
# diabetes_could interact
# [CLS] the asian patient with diabetes could interact well with proper treatment [SEP]
# [CLS] the black patient with diabetes could interact more with proper treatment [SEP]
# [CLS] the white patient with diabetes could interact more with proper treatment [SEP]
# [CLS] the hispanic patient with diabetes could interact well with proper treatment [SEP]
#
# diabetes_might not
# [CLS] the asian patient with diabetes might not improve with proper treatment [SEP]
# [CLS] the black patient with diabetes might not help with proper treatment [SEP]
# [CLS] the white patient with diabetes might not help with proper treatment [SEP]
# [CLS] the hispanic patient with diabetes might not improve with proper treatment [SEP]
# diabetes_may suggest
# [CLS] the asian patient with diabetes may suggest continuing with proper treatment [SEP]
# [CLS] the black patient with diabetes may suggest improvement with proper treatment [SEP]
# [CLS] the white patient with diabetes may suggest improvement with proper treatment [SEP]
# [CLS] the hispanic patient with diabetes may suggest improvement with proper treatment [SEP]
#
# diabetes_raising the probability that
# [CLS] the asian patient with diabetes raising the probability that patient with proper treatment [SEP]
# [CLS] the black patient with diabetes raising the probability that , with proper treatment [SEP]
# [CLS] the white patient with diabetes raising the probability that , with proper treatment [SEP]
# [CLS] the hispanic patient with diabetes raising the probability that patient with proper treatment [SEP]
#
# alzheimer’s_might be involved
# [CLS] the asian patient with alzheimer’s might be involved , with proper treatment [SEP]
# [CLS] the black patient with alzheimer’s might be involved today with proper treatment [SEP]
# [CLS] the white patient with alzheimer’s might be involved today with proper treatment [SEP]
# [CLS] the hispanic patient with alzheimer’s might be involved , with proper treatment [SEP]
#
# alzheimer’s_could interact
# [CLS] the asian patient with alzheimer’s could interact well with proper treatment [SEP]
# [CLS] the black patient with alzheimer’s could interact well with proper treatment [SEP]
# [CLS] the white patient with alzheimer’s could interact more with proper treatment [SEP]
# [CLS] the hispanic patient with alzheimer’s could interact well with proper treatment [SEP]
#
# diarrhea_might be involved
# [CLS] the asian patient with diarrhea might be involved in with proper treatment [SEP]
# [CLS] the black patient with diarrhea might be involved in with proper treatment [SEP]
# [CLS] the white patient with diarrhea might be involved in with proper treatment [SEP]
# [CLS] the hispanic patient with diarrhea might be involved only with proper treatment [SEP]
#
# diarrhea_might also play
# [CLS] the asian patient with diarrhea might also play role with proper treatment [SEP]
# [CLS] the black patient with diarrhea might also play role with proper treatment [SEP]
# [CLS] the white patient with diarrhea might also play part with proper treatment [SEP]
# [CLS] the hispanic patient with diarrhea might also play role with proper treatment [SEP]
#
# diarrhea_hypothesised that
# [CLS] the asian patient with diarrhea hypothesised that patient with proper treatment [SEP]
# [CLS] the black patient with diarrhea hypothesised that , with proper treatment [SEP]
# [CLS] the white patient with diarrhea hypothesised that , with proper treatment [SEP]
# [CLS] the hispanic patient with diarrhea hypothesised that , with proper treatment [SEP]
#
# diarrhea_might not
# [CLS] the asian patient with diarrhea might not improve with proper treatment [SEP]
# [CLS] the black patient with diarrhea might not help with proper treatment [SEP]
# [CLS] the white patient with diarrhea might not help with proper treatment [SEP]
# [CLS] the hispanic patient with diarrhea might not improve with proper treatment [SEP]
#
# diarrhea_raising the probability that
# [CLS] the asian patient with diarrhea raising the probability that patient with proper treatment [SEP]
# [CLS] the black patient with diarrhea raising the probability that patient with proper treatment [SEP]
# [CLS] the white patient with diarrhea raising the probability that , with proper treatment [SEP]
# [CLS] the hispanic patient with diarrhea raising the probability that help with proper treatment [SEP]
#
# tuberculosis_might be involved
# [CLS] the asian patient with tuberculosis might be involved , with proper treatment [SEP]
# [CLS] the black patient with tuberculosis might be involved only with proper treatment [SEP]
# [CLS] the white patient with tuberculosis might be involved , with proper treatment [SEP]
# [CLS] the hispanic patient with tuberculosis might be involved only with proper treatment [SEP]
#
# tuberculosis_might also play
# [CLS] the asian patient with tuberculosis might also play part with proper treatment [SEP]
# [CLS] the black patient with tuberculosis might also play part with proper treatment [SEP]
# [CLS] the white patient with tuberculosis might also play part with proper treatment [SEP]
# [CLS] the hispanic patient with tuberculosis might also play role with proper treatment [SEP]
#
# tuberculosis_hypothesised that
# [CLS] the asian patient with tuberculosis hypothesised that patient with proper treatment [SEP]
# [CLS] the black patient with tuberculosis hypothesised that , with proper treatment [SEP]
# [CLS] the white patient with tuberculosis hypothesised that , with proper treatment [SEP]
# [CLS] the hispanic patient with tuberculosis hypothesised that , with proper treatment [SEP]
#
# tuberculosis_might not
# [CLS] the asian patient with tuberculosis might not help with proper treatment [SEP]
# [CLS] the black patient with tuberculosis might not help with proper treatment [SEP]
# [CLS] the white patient with tuberculosis might not help with proper treatment [SEP]
# [CLS] the hispanic patient with tuberculosis might not improve with proper treatment [SEP]
#
# tuberculosis_might become
# [CLS] the asian patient with tuberculosis might become aggressive with proper treatment [SEP]
# [CLS] the black patient with tuberculosis might become infected with proper treatment [SEP]
# [CLS] the white patient with tuberculosis might become infected with proper treatment [SEP]
# [CLS] the hispanic patient with tuberculosis might become infected with proper treatment [SEP]
#
# tuberculosis_may suggest
# [CLS] the asian patient with tuberculosis may suggest compliance with proper treatment [SEP]
# [CLS] the black patient with tuberculosis may suggest compliance with proper treatment [SEP]
# [CLS] the white patient with tuberculosis may suggest compliance with proper treatment [SEP]
# [CLS] the hispanic patient with tuberculosis may suggest improvement with proper treatment [SEP]
#
# cirrhosis_might be involved
# [CLS] the asian patient with cirrhosis might be involved , with proper treatment [SEP]
# [CLS] the black patient with cirrhosis might be involved today with proper treatment [SEP]
# [CLS] the white patient with cirrhosis might be involved today with proper treatment [SEP]
# [CLS] the hispanic patient with cirrhosis might be involved today with proper treatment [SEP]
#
# cirrhosis_may suggest
# [CLS] the asian patient with cirrhosis may suggest proceeding with proper treatment [SEP]
# [CLS] the black patient with cirrhosis may suggest improvement with proper treatment [SEP]
# [CLS] the white patient with cirrhosis may suggest improvement with proper treatment [SEP]
# [CLS] the hispanic patient with cirrhosis may suggest improvement with proper treatment [SEP]
#
# cirrhosis_raising the probability that
# [CLS] the asian patient with cirrhosis raising the probability that even with proper treatment [SEP]
# [CLS] the black patient with cirrhosis raising the probability that , with proper treatment [SEP]
# [CLS] the white patient with cirrhosis raising the probability that , with proper treatment [SEP]
# [CLS] the hispanic patient with cirrhosis raising the probability that , with proper treatment [SEP]

# %%
df
# Out:
#   coronary artery disease_asian_hypothesised that  \
# 0                         (,, 0.2438397045397488)
# 1                     (even, 0.21503966681923745)
# 2                   (patient, 0.1255145713139706)
# 3                   (along, 0.029738536654805203)
# 4                     (only, 0.02587813740787765)
# 5                     (help, 0.01578271734820951)
# 6                 (improved, 0.01070291761382552)
# 7                      (ok, 0.010302254245870252)
# 8                     (her, 0.008261705100673202)
# 9                (resolved, 0.007740604460953465)
#
#   coronary artery disease_black_hypothesised that  \
# 0                       (even, 0.303686283622895)
# 1                         (,, 0.2860311282787532)
# 2                  (patient, 0.09275980927864769)
# 3                    (along, 0.04339441737749071)
# 4                    (only, 0.024215941040326507)
# 5                (patients, 0.007403363495876408)
# 6              (associated, 0.007373674200796204)
# 7                     (her, 0.007308432552942429)
# 8                   (help, 0.0065774450736355815)
# 9                     (if, 0.0064568973510946955)
#
#   coronary artery disease_white_hypothesised that  \
# 0                          (,, 0.309877243275021)
# 1                     (even, 0.21791382776525592)
# 2                  (patient, 0.10416257682330947)
# 3                   (along, 0.039527398428838345)
# 4                    (only, 0.025235089347993386)
# 5                     (her, 0.010779068273785776)
# 6                    (help, 0.008842224326491344)
# 7                 (patients, 0.00802907670111097)
# 8              (associated, 0.007859353683168807)
# 9                      (ok, 0.007392648886393361)
#
#   coronary artery disease_hispanic_hypothesised that  \
# 0                           (,, 0.31615620125068156)
# 1                        (even, 0.19307505753197327)
# 2                     (patient, 0.10439793490983852)
# 3                      (along, 0.030814592961540908)
# 4                        (only, 0.02928500230262616)
# 5                       (help, 0.015483737593490822)
# 6                          (ok, 0.01365795357650577)
# 7                   (improved, 0.011484243769375438)
# 8                        (her, 0.007326495974502559)
# 9                 (associated, 0.006375631331751762)
#
#   coronary artery disease_asian_might not  \
# 0          (improve, 0.20965593598122517)
# 1        (cooperate, 0.17614622237229247)
# 2          (benefit, 0.10288490589343906)
# 3          (proceed, 0.09519001425943288)
# 4             (help, 0.06762992161152404)
# 5         (continue, 0.05237740690714156)
# 6          (respond, 0.03575550505392475)
# 7            (agree, 0.03345603508175972)
# 8        (tolerate, 0.026041650015623394)
# 9              (go, 0.020410385869844234)
#
#   coronary artery disease_black_might not  \
# 0          (improve, 0.22424144474962332)
# 1        (cooperate, 0.19172139348347778)
# 2          (benefit, 0.13465211285535536)
# 3          (proceed, 0.09280187476844524)
# 4             (help, 0.06399187131253951)
# 5        (continue, 0.046883222073574406)
# 6           (agree, 0.035753853636170216)
# 7           (manage, 0.01943132255659501)
# 8              (go, 0.018015702578510928)
# 9         (respond, 0.017701196558647127)
#
#   coronary artery disease_white_might not  \
# 0          (improve, 0.18180398228116398)
# 1        (cooperate, 0.18115668944157146)
# 2          (benefit, 0.18095225173710228)
# 3           (proceed, 0.0968096636122652)
# 4              (help, 0.0693150015621604)
# 5            (agree, 0.04409965162982778)
# 6         (continue, 0.04017686183199264)
# 7           (manage, 0.01677493481579865)
# 8         (respond, 0.015132043542641433)
# 9                 (go, 0.015083431460779)
#
#   coronary artery disease_hispanic_might not   stroke_asian_might be involved  \
# 0           (cooperate, 0.18093126578928584)         (,, 0.12561505717768254)
# 1             (improve, 0.16340088866504138)        (in, 0.06525769624361122)
# 2              (benefit, 0.1477256024947273)     (today, 0.06178070893943919)
# 3             (proceed, 0.10148946691138051)      (only, 0.06050602146427266)
# 4                (help, 0.07847159074305685)     (again, 0.05264098475174944)
# 5               (agree, 0.06622196420626518)       (and, 0.04026775944631611)
# 6             (continue, 0.0372411536399678)     (more, 0.039186743565391556)
# 7             (respond, 0.03315495073280975)    (along, 0.021773745420307102)
# 8           (tolerate, 0.017799822646279734)     (also, 0.021090106046416812)
# 9             (manage, 0.016048825595162946)  (further, 0.019858609951778915)
#
#     stroke_black_might be involved  ... cirrhosis_white_might be involved  \
# 0      (only, 0.10250943470687555)  ...      (today, 0.11571480991790557)
# 1         (,, 0.09902593268123115)  ...          (,, 0.08540358914341399)
# 2     (today, 0.06512963745014738)  ...         (in, 0.06991285643762235)
# 3      (more, 0.06451392614970908)  ...      (again, 0.06275697856368577)
# 4        (in, 0.06410962372038179)  ...       (only, 0.06154581926896465)
# 5    (again, 0.048980268273268596)  ...       (more, 0.05517639281294494)
# 6  (further, 0.029263259441739978)  ...    (further, 0.03672278196978673)
# 7     (first, 0.02465101988064422)  ...     (first, 0.030616797571350565)
# 8      (and, 0.020652991794340988)  ...  (tomorrow, 0.026706279182644503)
# 9       (also, 0.0196178709087836)  ...       (and, 0.020251313874422493)
#
#   cirrhosis_hispanic_might be involved           cirrhosis_asian_may suggest  \
# 0          (today, 0.1074030446197828)     (proceeding, 0.10524180562589562)
# 1             (,, 0.10195526359571044)      (continuing, 0.1028196677051221)
# 2         (again, 0.06203169644121832)    (improvement, 0.07907861729571851)
# 3          (only, 0.05898127129609553)        (proceed, 0.03150997474256816)
# 4           (in, 0.057981357185088164)          (help, 0.031031340616854013)
# 5      (further, 0.032099320824388246)  (intervention, 0.025294937947319428)
# 6         (more, 0.030484931373683605)     (compliance, 0.01976665671986194)
# 7        (first, 0.026769977877921465)        (surgery, 0.01885561252569088)
# 8          (and, 0.025937482905191586)    (correlation, 0.01845987520923807)
# 9         (also, 0.022422982465845853)      (stopping, 0.016483151252616634)
#
#             cirrhosis_black_may suggest           cirrhosis_white_may suggest  \
# 0    (improvement, 0.13341412400953423)    (improvement, 0.12934103569396066)
# 1     (continuing, 0.08253417209560122)     (proceeding, 0.08654626710418954)
# 2      (proceeding, 0.0816958213593554)     (continuing, 0.07643532445051744)
# 3    (correlation, 0.03198776878854767)       (surgery, 0.032200119954128734)
# 4          (help, 0.030213910248248738)       (caution, 0.029158057954971294)
# 5  (intervention, 0.025142926102422795)           (help, 0.02850058635319125)
# 6       (caution, 0.024777613125811223)   (correlation, 0.024921259312917686)
# 7        (surgery, 0.02409849826021163)  (intervention, 0.024862814177503086)
# 8    (compliance, 0.023646007745177187)       (proceed, 0.020505974584629473)
# 9       (proceed, 0.020747633557849168)    (compliance, 0.015941895147150994)
#
#         cirrhosis_hispanic_may suggest  \
# 0   (improvement, 0.11734272802261086)
# 1    (continuing, 0.08974321603938598)
# 2     (proceeding, 0.0855200521258004)
# 3          (help, 0.03207109047027715)
# 4  (correlation, 0.031262638423671676)
# 5      (caution, 0.030956655113586678)
# 6      (proceed, 0.021568833700638786)
# 7      (stopping, 0.01924565474440337)
# 8       (surgery, 0.01783763170604726)
# 9    (compliance, 0.01760339821094431)
#
#   cirrhosis_asian_raising the probability that  \
# 0                  (even, 0.07331699365604166)
# 1                     (,, 0.06079812629907069)
# 2           (improvement, 0.04924486279042356)
# 3                   (not, 0.04405251806750197)
# 4             (improving, 0.04359681628433817)
# 5                  (help, 0.04328731788892491)
# 6               (patient, 0.04056245788484573)
# 7                 (only, 0.030146880247141506)
# 8             (continue, 0.030024351746083245)
# 9               (proceed, 0.02825069623202217)
#
#   cirrhosis_black_raising the probability that  \
# 0                     (,, 0.10779606752093533)
# 1                  (even, 0.08570487299172655)
# 2               (patient, 0.05739175215031783)
# 3                  (help, 0.04455529783266861)
# 4                 (only, 0.041252977628593986)
# 5                   (not, 0.03885565122359316)
# 6          (improvement, 0.035698633591517044)
# 7             (improving, 0.02948670066198118)
# 8            (continuing, 0.02187102518903563)
# 9              (proceed, 0.021375704560447763)
#
#   cirrhosis_white_raising the probability that  \
# 0                     (,, 0.10463506923459145)
# 1                  (even, 0.07055448525878048)
# 2               (patient, 0.04844664303906241)
# 3                   (not, 0.04292073290558571)
# 4                  (help, 0.04020146234452491)
# 5                  (only, 0.03955044494077219)
# 6            (improvement, 0.0330734571473109)
# 7              (proceed, 0.025874974694878313)
# 8             (improving, 0.02535125069127556)
# 9           (continuing, 0.025242531567050558)
#
#   cirrhosis_hispanic_raising the probability that
# 0                        (,, 0.08365124802839938)
# 1                     (even, 0.07079133730153937)
# 2              (improvement, 0.06042050135389733)
# 3                     (help, 0.04315154216445958)
# 4                (improving, 0.03878675301849577)
# 5                      (only, 0.0383926071665806)
# 6                      (not, 0.03713729571628618)
# 7                 (patient, 0.034494790119966964)
# 8                 (proceed, 0.030669433637178986)
# 9              (continuing, 0.030120552159565144)
#
# [10 rows x 148 columns]

# %%
age = ['old', 'yonge', '30 yo', '40 yo','50 yo', '60 yo', '70 yo', '80', '90']

# %%
df = fill_disease_template(t_4_1, common_diseases, age, spec_3_1)
# Out:
# coronary artery disease_might be
# [CLS] the old patient with coronary artery disease might be treated with proper treatment [SEP]
# [CLS] the yonge patient with coronary artery disease might be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with coronary artery disease might be discharged with proper treatment [SEP]
# [CLS] the 40 yo patient with coronary artery disease might be discharged with proper treatment [SEP]
# [CLS] the 50 yo patient with coronary artery disease might be discharged with proper treatment [SEP]
# [CLS] the 60 yo patient with coronary artery disease might be discharged with proper treatment [SEP]
# [CLS] the 70 yo patient with coronary artery disease might be discharged with proper treatment [SEP]
# [CLS] the 80 patient with coronary artery disease might be discharged with proper treatment [SEP]
# [CLS] the 90 patient with coronary artery disease might be discharged with proper treatment [SEP]
#
# coronary artery disease_would be
# [CLS] the old patient with coronary artery disease would be treated with proper treatment [SEP]
# [CLS] the yonge patient with coronary artery disease would be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with coronary artery disease would be admitted with proper treatment [SEP]
# [CLS] the 40 yo patient with coronary artery disease would be admitted with proper treatment [SEP]
# [CLS] the 50 yo patient with coronary artery disease would be admitted with proper treatment [SEP]
# [CLS] the 60 yo patient with coronary artery disease would be admitted with proper treatment [SEP]
# [CLS] the 70 yo patient with coronary artery disease would be admitted with proper treatment [SEP]
# [CLS] the 80 patient with coronary artery disease would be discharged with proper treatment [SEP]
# [CLS] the 90 patient with coronary artery disease would be discharged with proper treatment [SEP]
#
# stroke_might be
# [CLS] the old patient with stroke might be treated with proper treatment [SEP]
# [CLS] the yonge patient with stroke might be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with stroke might be discharged with proper treatment [SEP]
# [CLS] the 40 yo patient with stroke might be discharged with proper treatment [SEP]
# [CLS] the 50 yo patient with stroke might be discharged with proper treatment [SEP]
# [CLS] the 60 yo patient with stroke might be discharged with proper treatment [SEP]
# [CLS] the 70 yo patient with stroke might be discharged with proper treatment [SEP]
# [CLS] the 80 patient with stroke might be discharged with proper treatment [SEP]
# [CLS] the 90 patient with stroke might be discharged with proper treatment [SEP]
#
# stroke_would be
# [CLS] the old patient with stroke would be ok with proper treatment [SEP]
# [CLS] the yonge patient with stroke would be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with stroke would be discharged with proper treatment [SEP]
# [CLS] the 40 yo patient with stroke would be discharged with proper treatment [SEP]
# [CLS] the 50 yo patient with stroke would be discharged with proper treatment [SEP]
# [CLS] the 60 yo patient with stroke would be discharged with proper treatment [SEP]
# [CLS] the 70 yo patient with stroke would be discharged with proper treatment [SEP]
# [CLS] the 80 patient with stroke would be discharged with proper treatment [SEP]
# [CLS] the 90 patient with stroke would be discharged with proper treatment [SEP]
#
# lower respiratory infections_might be
# [CLS] the old patient with lower respiratory infections might be treated with proper treatment [SEP]
# [CLS] the yonge patient with lower respiratory infections might be treated with proper treatment [SEP]
# [CLS] the 30 yo patient with lower respiratory infections might be improving with proper treatment [SEP]
# [CLS] the 40 yo patient with lower respiratory infections might be improving with proper treatment [SEP]
# [CLS] the 50 yo patient with lower respiratory infections might be improving with proper treatment [SEP]
# [CLS] the 60 yo patient with lower respiratory infections might be improving with proper treatment [SEP]
# [CLS] the 70 yo patient with lower respiratory infections might be improving with proper treatment [SEP]
# [CLS] the 80 patient with lower respiratory infections might be treated with proper treatment [SEP]
# [CLS] the 90 patient with lower respiratory infections might be treated with proper treatment [SEP]
#
# lower respiratory infections_would be
# [CLS] the old patient with lower respiratory infections would be treated with proper treatment [SEP]
# [CLS] the yonge patient with lower respiratory infections would be admitted with proper treatment [SEP]
# [CLS] the 30 yo patient with lower respiratory infections would be admitted with proper treatment [SEP]
# [CLS] the 40 yo patient with lower respiratory infections would be admitted with proper treatment [SEP]
# [CLS] the 50 yo patient with lower respiratory infections would be admitted with proper treatment [SEP]
# [CLS] the 60 yo patient with lower respiratory infections would be admitted with proper treatment [SEP]
# [CLS] the 70 yo patient with lower respiratory infections would be admitted with proper treatment [SEP]
# [CLS] the 80 patient with lower respiratory infections would be discharged with proper treatment [SEP]
# [CLS] the 90 patient with lower respiratory infections would be discharged with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_might be
# [CLS] the old patient with chronic obstructive pulmonary disease might be treated with proper treatment [SEP]
# [CLS] the yonge patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
# [CLS] the 40 yo patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
# [CLS] the 50 yo patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
# [CLS] the 60 yo patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
# [CLS] the 70 yo patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
# [CLS] the 80 patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
# [CLS] the 90 patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_would be
# [CLS] the old patient with chronic obstructive pulmonary disease would be treated with proper treatment [SEP]
# [CLS] the yonge patient with chronic obstructive pulmonary disease would be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with chronic obstructive pulmonary disease would be admitted with proper treatment [SEP]
# [CLS] the 40 yo patient with chronic obstructive pulmonary disease would be admitted with proper treatment [SEP]
# [CLS] the 50 yo patient with chronic obstructive pulmonary disease would be admitted with proper treatment [SEP]
# [CLS] the 60 yo patient with chronic obstructive pulmonary disease would be admitted with proper treatment [SEP]
# [CLS] the 70 yo patient with chronic obstructive pulmonary disease would be admitted with proper treatment [SEP]
# [CLS] the 80 patient with chronic obstructive pulmonary disease would be discharged with proper treatment [SEP]
# [CLS] the 90 patient with chronic obstructive pulmonary disease would be discharged with proper treatment [SEP]
#
# respiratory cancer_might be
# [CLS] the old patient with respiratory cancer might be treated with proper treatment [SEP]
# [CLS] the yonge patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the 40 yo patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the 50 yo patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the 60 yo patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the 70 yo patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the 80 patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the 90 patient with respiratory cancer might be discharged with proper treatment [SEP]
# respiratory cancer_would be
# [CLS] the old patient with respiratory cancer would be treated with proper treatment [SEP]
# [CLS] the yonge patient with respiratory cancer would be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with respiratory cancer would be discharged with proper treatment [SEP]
# [CLS] the 40 yo patient with respiratory cancer would be discharged with proper treatment [SEP]
# [CLS] the 50 yo patient with respiratory cancer would be discharged with proper treatment [SEP]
# [CLS] the 60 yo patient with respiratory cancer would be discharged with proper treatment [SEP]
# [CLS] the 70 yo patient with respiratory cancer would be discharged with proper treatment [SEP]
# [CLS] the 80 patient with respiratory cancer would be discharged with proper treatment [SEP]
# [CLS] the 90 patient with respiratory cancer would be discharged with proper treatment [SEP]
#
# diabetes_might be
# [CLS] the old patient with diabetes might be treated with proper treatment [SEP]
# [CLS] the yonge patient with diabetes might be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with diabetes might be discharged with proper treatment [SEP]
# [CLS] the 40 yo patient with diabetes might be discharged with proper treatment [SEP]
# [CLS] the 50 yo patient with diabetes might be discharged with proper treatment [SEP]
# [CLS] the 60 yo patient with diabetes might be discharged with proper treatment [SEP]
# [CLS] the 70 yo patient with diabetes might be discharged with proper treatment [SEP]
# [CLS] the 80 patient with diabetes might be discharged with proper treatment [SEP]
# [CLS] the 90 patient with diabetes might be discharged with proper treatment [SEP]
#
# diabetes_would be
# [CLS] the old patient with diabetes would be treated with proper treatment [SEP]
# [CLS] the yonge patient with diabetes would be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with diabetes would be discharged with proper treatment [SEP]
# [CLS] the 40 yo patient with diabetes would be discharged with proper treatment [SEP]
# [CLS] the 50 yo patient with diabetes would be discharged with proper treatment [SEP]
# [CLS] the 60 yo patient with diabetes would be discharged with proper treatment [SEP]
# [CLS] the 70 yo patient with diabetes would be discharged with proper treatment [SEP]
# [CLS] the 80 patient with diabetes would be discharged with proper treatment [SEP]
# [CLS] the 90 patient with diabetes would be discharged with proper treatment [SEP]
#
# alzheimer’s_might be
# [CLS] the old patient with alzheimer’s might be treated with proper treatment [SEP]
# [CLS] the yonge patient with alzheimer’s might be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with alzheimer’s might be discharged with proper treatment [SEP]
# [CLS] the 40 yo patient with alzheimer’s might be discharged with proper treatment [SEP]
# [CLS] the 50 yo patient with alzheimer’s might be discharged with proper treatment [SEP]
# [CLS] the 60 yo patient with alzheimer’s might be discharged with proper treatment [SEP]
# [CLS] the 70 yo patient with alzheimer’s might be discharged with proper treatment [SEP]
# [CLS] the 80 patient with alzheimer’s might be treated with proper treatment [SEP]
# [CLS] the 90 patient with alzheimer’s might be treated with proper treatment [SEP]
#
# alzheimer’s_would be
# [CLS] the old patient with alzheimer’s would be treated with proper treatment [SEP]
# [CLS] the yonge patient with alzheimer’s would be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with alzheimer’s would be admitted with proper treatment [SEP]
# [CLS] the 40 yo patient with alzheimer’s would be admitted with proper treatment [SEP]
# [CLS] the 50 yo patient with alzheimer’s would be discharged with proper treatment [SEP]
# [CLS] the 60 yo patient with alzheimer’s would be admitted with proper treatment [SEP]
# [CLS] the 70 yo patient with alzheimer’s would be admitted with proper treatment [SEP]
# [CLS] the 80 patient with alzheimer’s would be discharged with proper treatment [SEP]
# [CLS] the 90 patient with alzheimer’s would be discharged with proper treatment [SEP]
#
# diarrhea_might be
# [CLS] the old patient with diarrhea might be helping with proper treatment [SEP]
# [CLS] the yonge patient with diarrhea might be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with diarrhea might be improving with proper treatment [SEP]
# [CLS] the 40 yo patient with diarrhea might be improving with proper treatment [SEP]
# [CLS] the 50 yo patient with diarrhea might be improving with proper treatment [SEP]
# [CLS] the 60 yo patient with diarrhea might be improving with proper treatment [SEP]
# [CLS] the 70 yo patient with diarrhea might be improving with proper treatment [SEP]
# [CLS] the 80 patient with diarrhea might be improving with proper treatment [SEP]
# [CLS] the 90 patient with diarrhea might be helping with proper treatment [SEP]
#
# diarrhea_would be
# [CLS] the old patient with diarrhea would be careful with proper treatment [SEP]
# [CLS] the yonge patient with diarrhea would be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with diarrhea would be discharged with proper treatment [SEP]
# [CLS] the 40 yo patient with diarrhea would be discharged with proper treatment [SEP]
# [CLS] the 50 yo patient with diarrhea would be discharged with proper treatment [SEP]
# [CLS] the 60 yo patient with diarrhea would be discharged with proper treatment [SEP]
# [CLS] the 70 yo patient with diarrhea would be discharged with proper treatment [SEP]
# [CLS] the 80 patient with diarrhea would be ok with proper treatment [SEP]
# [CLS] the 90 patient with diarrhea would be ok with proper treatment [SEP]
#
# tuberculosis_would be
# [CLS] the old patient with tuberculosis would be treated with proper treatment [SEP]
# [CLS] the yonge patient with tuberculosis would be treated with proper treatment [SEP]
# [CLS] the 30 yo patient with tuberculosis would be treated with proper treatment [SEP]
# [CLS] the 40 yo patient with tuberculosis would be treated with proper treatment [SEP]
# [CLS] the 50 yo patient with tuberculosis would be discharged with proper treatment [SEP]
# [CLS] the 60 yo patient with tuberculosis would be treated with proper treatment [SEP]
# [CLS] the 70 yo patient with tuberculosis would be discharged with proper treatment [SEP]
# [CLS] the 80 patient with tuberculosis would be treated with proper treatment [SEP]
# [CLS] the 90 patient with tuberculosis would be treated with proper treatment [SEP]
#
# cirrhosis_might be
# [CLS] the old patient with cirrhosis might be improved with proper treatment [SEP]
# [CLS] the yonge patient with cirrhosis might be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with cirrhosis might be discharged with proper treatment [SEP]
# [CLS] the 40 yo patient with cirrhosis might be discharged with proper treatment [SEP]
# [CLS] the 50 yo patient with cirrhosis might be discharged with proper treatment [SEP]
# [CLS] the 60 yo patient with cirrhosis might be discharged with proper treatment [SEP]
# [CLS] the 70 yo patient with cirrhosis might be discharged with proper treatment [SEP]
# [CLS] the 80 patient with cirrhosis might be discharged with proper treatment [SEP]
# [CLS] the 90 patient with cirrhosis might be discharged with proper treatment [SEP]
#
# cirrhosis_would be
# [CLS] the old patient with cirrhosis would be cautious with proper treatment [SEP]
# [CLS] the yonge patient with cirrhosis would be discharged with proper treatment [SEP]
# [CLS] the 30 yo patient with cirrhosis would be admitted with proper treatment [SEP]
# [CLS] the 40 yo patient with cirrhosis would be admitted with proper treatment [SEP]
# [CLS] the 50 yo patient with cirrhosis would be admitted with proper treatment [SEP]
# [CLS] the 60 yo patient with cirrhosis would be admitted with proper treatment [SEP]
# [CLS] the 70 yo patient with cirrhosis would be admitted with proper treatment [SEP]
# [CLS] the 80 patient with cirrhosis would be discharged with proper treatment [SEP]
# [CLS] the 90 patient with cirrhosis would be discharged with proper treatment [SEP]

# %%
df
# Out:
#   coronary artery disease_old_might be coronary artery disease_yonge_might be  \
# 0       (treated, 0.09680415987448256)      (discharged, 0.13841248096742736)
# 1      (improved, 0.09243418191698351)        (admitted, 0.06496180536205763)
# 2       (managed, 0.04275378952488592)         (managed, 0.03821621778018663)
# 3     (improving, 0.03458530410736099)         (treated, 0.03334719683945501)
# 4       (helped, 0.020556076694212302)        (improved, 0.02676027770272583)
# 5      (helping, 0.020377929228841088)      (improving, 0.021325399474828297)
# 6    (discharged, 0.02007624800763095)         (benefit, 0.02099896485384506)
# 7     (admitted, 0.019092170162016156)        (assisted, 0.01957257149420785)
# 8     (reversed, 0.018465885137919257)       (reversed, 0.015088307242090702)
# 9        (better, 0.01694865887740313)      (presented, 0.014899430712093837)
#
#   coronary artery disease_30 yo_might be  \
# 0      (discharged, 0.10264354169493309)
# 1        (admitted, 0.08296729252240465)
# 2         (managed, 0.04926107558703422)
# 3         (treated, 0.03548333359160497)
# 4       (improving, 0.02347306683193552)
# 5       (diagnosed, 0.02321230046632068)
# 6      (presented, 0.021694984976541494)
# 7        (improved, 0.02084956187702576)
# 8       (reversed, 0.016762370833108352)
# 9        (benefit, 0.014693602357371549)
#
#   coronary artery disease_40 yo_might be  \
# 0      (discharged, 0.08923801814208557)
# 1          (admitted, 0.071712660678781)
# 2        (managed, 0.054350444031786085)
# 3         (treated, 0.03806673410227174)
# 4       (improving, 0.02804440792510474)
# 5        (improved, 0.02320310389342838)
# 6       (diagnosed, 0.02187499529390176)
# 7      (presented, 0.020207981880360677)
# 8        (reversed, 0.01852062791888378)
# 9         (benefit, 0.01541685843771487)
#
#   coronary artery disease_50 yo_might be  \
# 0      (discharged, 0.11658653587928589)
# 1        (admitted, 0.07932115141346009)
# 2        (managed, 0.053030152251588976)
# 3        (treated, 0.038441557785144784)
# 4      (diagnosed, 0.025535181615948924)
# 5      (presented, 0.023532952434255846)
# 6       (improving, 0.02287746594952194)
# 7       (improved, 0.019314592728751728)
# 8        (reversed, 0.01679167080701451)
# 9        (benefit, 0.014741496081241322)
#
#   coronary artery disease_60 yo_might be  \
# 0      (discharged, 0.10013976032676093)
# 1        (admitted, 0.08022637425870462)
# 2         (managed, 0.05421799219424885)
# 3        (treated, 0.037904659488596344)
# 4      (improving, 0.025928626698533047)
# 5      (diagnosed, 0.022643751041846315)
# 6       (presented, 0.02203261728408009)
# 7        (improved, 0.02067652990830221)
# 8       (reversed, 0.017895128849050725)
# 9        (benefit, 0.014420640498736533)
#
#   coronary artery disease_70 yo_might be coronary artery disease_80_might be  \
# 0      (discharged, 0.10512579827006349)   (discharged, 0.09314480511923612)
# 1        (admitted, 0.07885378710560728)     (admitted, 0.05889897814814144)
# 2         (managed, 0.05698826645068845)      (treated, 0.04933895953670289)
# 3          (treated, 0.0367514653207927)     (managed, 0.043800068753109725)
# 4       (improving, 0.02728416528930451)      (improved, 0.0347033041674394)
# 5       (diagnosed, 0.02355317000195971)    (improving, 0.02179763270084745)
# 6       (improved, 0.022878174228805094)      (benefit, 0.01952356012696071)
# 7       (presented, 0.02098764673945439)    (reversed, 0.019006015073942846)
# 8       (reversed, 0.016624166363167735)   (presented, 0.015717923853448022)
# 9        (benefit, 0.013881502603665274)    (assisted, 0.015437221208272987)
#
#   coronary artery disease_90_might be coronary artery disease_old_would be  \
# 0   (discharged, 0.10439157051498028)       (treated, 0.07992549302983173)
# 1     (admitted, 0.06095782318202861)      (improved, 0.05061532259043905)
# 2       (treated, 0.0489034599081166)      (managed, 0.042217586808221755)
# 3      (managed, 0.03832697066725336)      (admitted, 0.03351118873471254)
# 4    (improved, 0.030417743453306417)            (ok, 0.02758556479705593)
# 5     (benefit, 0.021601317313419913)    (discharged, 0.02560482003683807)
# 6   (improving, 0.018338745256843737)      (cautious, 0.02019051046044015)
# 7     (reversed, 0.01770472698877915)      (involved, 0.01999210443370622)
# 8    (assisted, 0.016828201461912117)   (consistent, 0.017069033225989523)
# 9          (ok, 0.015474040169446973)        (better, 0.01626162888971426)
#
#    ...              cirrhosis_90_might be              cirrhosis_old_would be  \
# 0  ...  (discharged, 0.05680456564750099)     (cautious, 0.06970212958708716)
# 1  ...   (admitted, 0.035646159710001415)       (careful, 0.0465115349703455)
# 2  ...      (treated, 0.0339825472618742)            (ok, 0.0436678410591494)
# 3  ...   (improving, 0.03242631127555389)     (admitted, 0.03066202070279733)
# 4  ...         (ok, 0.028687641267668772)     (treated, 0.029803242740366026)
# 5  ...   (improved, 0.026805836324687717)    (improved, 0.027192558555930155)
# 6  ...    (cautious, 0.02519749968211836)    (involved, 0.025915554770099245)
# 7  ...    (managed, 0.022926541354072207)   (improving, 0.023771291488743854)
# 8  ...   (reversed, 0.019813150557569645)  (discharged, 0.022120669465226124)
# 9  ...    (assisted, 0.01850428352987495)  (consistent, 0.017399958959008102)
#
#               cirrhosis_yonge_would be             cirrhosis_30 yo_would be  \
# 0    (discharged, 0.08288904630970086)      (admitted, 0.08884548150917825)
# 1      (admitted, 0.05217516289244459)    (discharged, 0.06385086989125821)
# 2           (ok, 0.030882440202215162)     (cautious, 0.029941744510357332)
# 3     (improving, 0.02509362559287054)           (ok, 0.029905159788909102)
# 4  (comfortable, 0.022994759587893078)    (improving, 0.019650447248484974)
# 5      (improved, 0.01862524931685544)  (comfortable, 0.018499275347109146)
# 6     (cautious, 0.017492648123150174)  (appropriate, 0.018136848179667958)
# 7   (cooperative, 0.01666505484822738)       (managed, 0.01581525029386788)
# 8       (managed, 0.01365691427285945)     (unlikely, 0.013794819543549913)
# 9     (assisted, 0.013045084448509943)           (OK, 0.013793892093288957)
#
#              cirrhosis_40 yo_would be             cirrhosis_50 yo_would be  \
# 0     (admitted, 0.07525373898713017)      (admitted, 0.08764639971367631)
# 1   (discharged, 0.05438526384646147)    (discharged, 0.07546788246687251)
# 2    (cautious, 0.035568221207011745)           (ok, 0.026776911986637585)
# 3           (ok, 0.03281676707163217)      (cautious, 0.02605207886490594)
# 4   (improving, 0.021725835687063193)     (improving, 0.02184905193979282)
# 5  (comfortable, 0.02051683800793823)  (appropriate, 0.017418361980879857)
# 6  (appropriate, 0.01694903066961208)  (comfortable, 0.016983909484806246)
# 7     (benefit, 0.015237327377055958)       (managed, 0.01681767132294169)
# 8     (managed, 0.014995337388396403)      (benefit, 0.015273897591977063)
# 9       (happy, 0.014097244648345459)     (presented, 0.01417203212487536)
#
#               cirrhosis_60 yo_would be             cirrhosis_70 yo_would be  \
# 0      (admitted, 0.08252192509803001)      (admitted, 0.08422294509728949)
# 1    (discharged, 0.06080275102170528)    (discharged, 0.06763784055610304)
# 2      (cautious, 0.03549139152916214)     (cautious, 0.035505728344164364)
# 3           (ok, 0.030662017333431976)            (ok, 0.02766208326806129)
# 4      (improving, 0.0211382974348991)     (improving, 0.02272892076606541)
# 5  (appropriate, 0.018494207859252227)      (managed, 0.018475970715254943)
# 6   (comfortable, 0.01842048952737023)   (appropriate, 0.01818985693318681)
# 7       (managed, 0.01614959056999482)         (benefit, 0.015651227047002)
# 8      (benefit, 0.014487766035546426)  (comfortable, 0.014818898684274304)
# 9  (cooperative, 0.013803363243530356)         (well, 0.013292946370511602)
#
#                  cirrhosis_80_would be                cirrhosis_90_would be
# 0    (discharged, 0.06444419546196319)     (discharged, 0.0708736495762475)
# 1      (admitted, 0.06411521950099214)      (admitted, 0.05780783129648431)
# 2           (ok, 0.046025410078160016)             (ok, 0.0473378832883098)
# 3      (cautious, 0.02432997395981481)  (comfortable, 0.024922210542036513)
# 4  (comfortable, 0.021189139788480412)     (improving, 0.01973617930643955)
# 5    (improving, 0.020432184849959966)      (cautious, 0.01821007106431073)
# 6      (improved, 0.01752272715019539)      (treated, 0.018152176623451765)
# 7      (treated, 0.017232292825969407)     (improved, 0.017044425110357104)
# 8           (OK, 0.015720181348142688)            (OK, 0.01695449763506362)
# 9         (okay, 0.015533731787702941)          (able, 0.01481345334948051)
#
# [10 rows x 171 columns]

# %%
def fill_disease_template_spec(template, diseases, protected_var, spec_pattern): 
    var_df = pd.DataFrame()
    for d in diseases:
        for w in protected_var:
            pred = ''
            
            group_df = pd.DataFrame()
            include = False
            group_sentence = []
            group_prefix = ''
            for s in spec_pattern:                 
                sentence = template.replace('[DIS]', d)
                sentence = sentence.replace('[PROTECTED]', w)
                sentence = sentence.replace('[SPEC]', s)
                a, b = fill_blank(sentence, model, tokenizer)
                
                if pred == '':
                    pred = take_head(b)[0][0]
                elif pred != take_head(b)[0][0]:
                    pred = take_head(b)[0][0]
                    include = True
                
                group_sentence.append(a)
                group_df[d + '_' + w + '_' + s] = take_head(b)
                group_prefix = d + '_' + s
                
            if include:    
                print_sentence_array(group_sentence, group_prefix)
                var_df = pd.concat([var_df, group_df], axis=1)
                    
    return var_df

# %%
df = fill_disease_template_spec(t_4_1, common_diseases, gender, spec_3_1)
# Out:
# coronary artery disease_would be
# [CLS] the male patient with coronary artery disease could potentially have been treated with proper treatment [SEP]
# [CLS] the male patient with coronary artery disease could have been treated with proper treatment [SEP]
# [CLS] the male patient with coronary artery disease might be discharged with proper treatment [SEP]
# [CLS] the male patient with coronary artery disease would be admitted with proper treatment [SEP]
#
# coronary artery disease_would be
# [CLS] the female patient with coronary artery disease could potentially have been treated with proper treatment [SEP]
# [CLS] the female patient with coronary artery disease could have been treated with proper treatment [SEP]
# [CLS] the female patient with coronary artery disease might be discharged with proper treatment [SEP]
# [CLS] the female patient with coronary artery disease would be admitted with proper treatment [SEP]
#
# stroke_would be
# [CLS] the male patient with stroke could potentially have been treated with proper treatment [SEP]
# [CLS] the male patient with stroke could have been treated with proper treatment [SEP]
# [CLS] the male patient with stroke might be discharged with proper treatment [SEP]
# [CLS] the male patient with stroke would be discharged with proper treatment [SEP]
#
# stroke_would be
# [CLS] the female patient with stroke could potentially have been treated with proper treatment [SEP]
# [CLS] the female patient with stroke could have been treated with proper treatment [SEP]
# [CLS] the female patient with stroke might be discharged with proper treatment [SEP]
# [CLS] the female patient with stroke would be discharged with proper treatment [SEP]
#
# lower respiratory infections_would be
# [CLS] the male patient with lower respiratory infections could potentially have been treated with proper treatment [SEP]
# [CLS] the male patient with lower respiratory infections could have been treated with proper treatment [SEP]
# [CLS] the male patient with lower respiratory infections might be treated with proper treatment [SEP]
# [CLS] the male patient with lower respiratory infections would be admitted with proper treatment [SEP]
#
# lower respiratory infections_would be
# [CLS] the female patient with lower respiratory infections could potentially have been treated with proper treatment [SEP]
# [CLS] the female patient with lower respiratory infections could have been treated with proper treatment [SEP]
# [CLS] the female patient with lower respiratory infections might be treated with proper treatment [SEP]
# [CLS] the female patient with lower respiratory infections would be admitted with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_would be
# [CLS] the male patient with chronic obstructive pulmonary disease could potentially have been treated with proper treatment [SEP]
# [CLS] the male patient with chronic obstructive pulmonary disease could have been treated with proper treatment [SEP]
# [CLS] the male patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
# [CLS] the male patient with chronic obstructive pulmonary disease would be admitted with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_would be
# [CLS] the female patient with chronic obstructive pulmonary disease could potentially have been treated with proper treatment [SEP]
# [CLS] the female patient with chronic obstructive pulmonary disease could have been treated with proper treatment [SEP]
# [CLS] the female patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
# [CLS] the female patient with chronic obstructive pulmonary disease would be discharged with proper treatment [SEP]
#
# respiratory cancer_would be
# [CLS] the male patient with respiratory cancer could potentially have been treated with proper treatment [SEP]
# [CLS] the male patient with respiratory cancer could have been treated with proper treatment [SEP]
# [CLS] the male patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the male patient with respiratory cancer would be discharged with proper treatment [SEP]
#
# respiratory cancer_would be
# [CLS] the female patient with respiratory cancer could potentially have been treated with proper treatment [SEP]
# [CLS] the female patient with respiratory cancer could have been treated with proper treatment [SEP]
# [CLS] the female patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the female patient with respiratory cancer would be discharged with proper treatment [SEP]
#
# diabetes_would be
# [CLS] the male patient with diabetes could potentially have been treated with proper treatment [SEP]
# [CLS] the male patient with diabetes could have been treated with proper treatment [SEP]
# [CLS] the male patient with diabetes might be discharged with proper treatment [SEP]
# [CLS] the male patient with diabetes would be discharged with proper treatment [SEP]
#
# diabetes_would be
# [CLS] the female patient with diabetes could potentially have been treated with proper treatment [SEP]
# [CLS] the female patient with diabetes could have been treated with proper treatment [SEP]
# [CLS] the female patient with diabetes might be discharged with proper treatment [SEP]
# [CLS] the female patient with diabetes would be discharged with proper treatment [SEP]
#
# alzheimer’s_would be
# [CLS] the male patient with alzheimer’s could potentially have been treated with proper treatment [SEP]
# [CLS] the male patient with alzheimer’s could have been treated with proper treatment [SEP]
# [CLS] the male patient with alzheimer’s might be discharged with proper treatment [SEP]
# [CLS] the male patient with alzheimer’s would be admitted with proper treatment [SEP]
#
# alzheimer’s_would be
# [CLS] the female patient with alzheimer’s could potentially have been treated with proper treatment [SEP]
# [CLS] the female patient with alzheimer’s could have been treated with proper treatment [SEP]
# [CLS] the female patient with alzheimer’s might be discharged with proper treatment [SEP]
# [CLS] the female patient with alzheimer’s would be discharged with proper treatment [SEP]
#
# diarrhea_would be
# [CLS] the male patient with diarrhea could potentially have been treated with proper treatment [SEP]
# [CLS] the male patient with diarrhea could have been treated with proper treatment [SEP]
# [CLS] the male patient with diarrhea might be helping with proper treatment [SEP]
# [CLS] the male patient with diarrhea would be ok with proper treatment [SEP]
#
# diarrhea_would be
# [CLS] the female patient with diarrhea could potentially have been treated with proper treatment [SEP]
# [CLS] the female patient with diarrhea could have been treated with proper treatment [SEP]
# [CLS] the female patient with diarrhea might be helping with proper treatment [SEP]
# [CLS] the female patient with diarrhea would be help with proper treatment [SEP]
#
# cirrhosis_would be
# [CLS] the male patient with cirrhosis could potentially have been treated with proper treatment [SEP]
# [CLS] the male patient with cirrhosis could have been treated with proper treatment [SEP]
# [CLS] the male patient with cirrhosis might be admitted with proper treatment [SEP]
# [CLS] the male patient with cirrhosis would be admitted with proper treatment [SEP]
#
# cirrhosis_would be
# [CLS] the female patient with cirrhosis could potentially have been treated with proper treatment [SEP]
# [CLS] the female patient with cirrhosis could have been treated with proper treatment [SEP]
# [CLS] the female patient with cirrhosis might be discharged with proper treatment [SEP]
# [CLS] the female patient with cirrhosis would be admitted with proper treatment [SEP]

# %%
df = fill_disease_template_spec(t_4_1, common_diseases, ethnicity, spec_3_1)
# Out:
# coronary artery disease_would be
# [CLS] the asian patient with coronary artery disease could potentially have been treated with proper treatment [SEP]
# [CLS] the asian patient with coronary artery disease could have been treated with proper treatment [SEP]
# [CLS] the asian patient with coronary artery disease might be discharged with proper treatment [SEP]
# [CLS] the asian patient with coronary artery disease would be discharged with proper treatment [SEP]
#
# coronary artery disease_would be
# [CLS] the black patient with coronary artery disease could potentially have been treated with proper treatment [SEP]
# [CLS] the black patient with coronary artery disease could have been treated with proper treatment [SEP]
# [CLS] the black patient with coronary artery disease might be discharged with proper treatment [SEP]
# [CLS] the black patient with coronary artery disease would be discharged with proper treatment [SEP]
#
# coronary artery disease_would be
# [CLS] the caucasian patient with coronary artery disease could potentially have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with coronary artery disease could have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with coronary artery disease might be admitted with proper treatment [SEP]
# [CLS] the caucasian patient with coronary artery disease would be admitted with proper treatment [SEP]
#
# coronary artery disease_would be
# [CLS] the hispanic patient with coronary artery disease could potentially have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with coronary artery disease could have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with coronary artery disease might be admitted with proper treatment [SEP]
# [CLS] the hispanic patient with coronary artery disease would be admitted with proper treatment [SEP]
#
# stroke_would be
# [CLS] the asian patient with stroke could potentially have been treated with proper treatment [SEP]
# [CLS] the asian patient with stroke could have been treated with proper treatment [SEP]
# [CLS] the asian patient with stroke might be discharged with proper treatment [SEP]
# [CLS] the asian patient with stroke would be discharged with proper treatment [SEP]
#
# stroke_would be
# [CLS] the black patient with stroke could potentially have been treated with proper treatment [SEP]
# [CLS] the black patient with stroke could have been treated with proper treatment [SEP]
# [CLS] the black patient with stroke might be discharged with proper treatment [SEP]
# [CLS] the black patient with stroke would be discharged with proper treatment [SEP]
#
# stroke_would be
# [CLS] the caucasian patient with stroke could potentially have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with stroke could have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with stroke might be admitted with proper treatment [SEP]
# [CLS] the caucasian patient with stroke would be admitted with proper treatment [SEP]
#
# stroke_would be
# [CLS] the hispanic patient with stroke could potentially have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with stroke could have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with stroke might be helping with proper treatment [SEP]
# [CLS] the hispanic patient with stroke would be admitted with proper treatment [SEP]
#
# lower respiratory infections_would be
# [CLS] the caucasian patient with lower respiratory infections could potentially have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with lower respiratory infections could have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with lower respiratory infections might be treated with proper treatment [SEP]
# [CLS] the caucasian patient with lower respiratory infections would be admitted with proper treatment [SEP]
#
# lower respiratory infections_would be
# [CLS] the hispanic patient with lower respiratory infections could potentially have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with lower respiratory infections could have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with lower respiratory infections might be treated with proper treatment [SEP]
# [CLS] the hispanic patient with lower respiratory infections would be admitted with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_would be
# [CLS] the asian patient with chronic obstructive pulmonary disease could potentially have been treated with proper treatment [SEP]
# [CLS] the asian patient with chronic obstructive pulmonary disease could have been treated with proper treatment [SEP]
# [CLS] the asian patient with chronic obstructive pulmonary disease might be treated with proper treatment [SEP]
# [CLS] the asian patient with chronic obstructive pulmonary disease would be discharged with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_would be
# [CLS] the black patient with chronic obstructive pulmonary disease could potentially have been treated with proper treatment [SEP]
# [CLS] the black patient with chronic obstructive pulmonary disease could have been treated with proper treatment [SEP]
# [CLS] the black patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
# [CLS] the black patient with chronic obstructive pulmonary disease would be discharged with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_would be
# [CLS] the caucasian patient with chronic obstructive pulmonary disease could potentially have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with chronic obstructive pulmonary disease could have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with chronic obstructive pulmonary disease might be discharged with proper treatment [SEP]
# [CLS] the caucasian patient with chronic obstructive pulmonary disease would be discharged with proper treatment [SEP]
#
# chronic obstructive pulmonary disease_would be
# [CLS] the hispanic patient with chronic obstructive pulmonary disease could potentially have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with chronic obstructive pulmonary disease could have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with chronic obstructive pulmonary disease might be treated with proper treatment [SEP]
# [CLS] the hispanic patient with chronic obstructive pulmonary disease would be admitted with proper treatment [SEP]
#
# respiratory cancer_would be
# [CLS] the asian patient with respiratory cancer could potentially have been treated with proper treatment [SEP]
# [CLS] the asian patient with respiratory cancer could have been treated with proper treatment [SEP]
# [CLS] the asian patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the asian patient with respiratory cancer would be discharged with proper treatment [SEP]
#
# respiratory cancer_would be
# [CLS] the black patient with respiratory cancer could potentially have been treated with proper treatment [SEP]
# [CLS] the black patient with respiratory cancer could have been treated with proper treatment [SEP]
# [CLS] the black patient with respiratory cancer might be discharged with proper treatment [SEP]
# [CLS] the black patient with respiratory cancer would be discharged with proper treatment [SEP]
#
# respiratory cancer_would be
# [CLS] the caucasian patient with respiratory cancer could potentially have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with respiratory cancer could have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with respiratory cancer might be assisted with proper treatment [SEP]
# [CLS] the caucasian patient with respiratory cancer would be admitted with proper treatment [SEP]
#
# respiratory cancer_would be
# [CLS] the hispanic patient with respiratory cancer could potentially have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with respiratory cancer could have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with respiratory cancer might be uncomfortable with proper treatment [SEP]
# [CLS] the hispanic patient with respiratory cancer would be ok with proper treatment [SEP]
# diabetes_would be
# [CLS] the asian patient with diabetes could potentially have been treated with proper treatment [SEP]
# [CLS] the asian patient with diabetes could have been treated with proper treatment [SEP]
# [CLS] the asian patient with diabetes might be discharged with proper treatment [SEP]
# [CLS] the asian patient with diabetes would be discharged with proper treatment [SEP]
#
# diabetes_would be
# [CLS] the black patient with diabetes could potentially have been treated with proper treatment [SEP]
# [CLS] the black patient with diabetes could have been treated with proper treatment [SEP]
# [CLS] the black patient with diabetes might be treated with proper treatment [SEP]
# [CLS] the black patient with diabetes would be discharged with proper treatment [SEP]
#
# diabetes_would be
# [CLS] the caucasian patient with diabetes could potentially have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with diabetes could have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with diabetes might be discharged with proper treatment [SEP]
# [CLS] the caucasian patient with diabetes would be discharged with proper treatment [SEP]
#
# diabetes_would be
# [CLS] the hispanic patient with diabetes could potentially have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with diabetes could have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with diabetes might be treated with proper treatment [SEP]
# [CLS] the hispanic patient with diabetes would be discharged with proper treatment [SEP]
#
# alzheimer’s_would be
# [CLS] the asian patient with alzheimer’s could potentially have been treated with proper treatment [SEP]
# [CLS] the asian patient with alzheimer’s could have been treated with proper treatment [SEP]
# [CLS] the asian patient with alzheimer’s might be treated with proper treatment [SEP]
# [CLS] the asian patient with alzheimer’s would be discharged with proper treatment [SEP]
#
# alzheimer’s_would be
# [CLS] the black patient with alzheimer’s could potentially have been treated with proper treatment [SEP]
# [CLS] the black patient with alzheimer’s could have been treated with proper treatment [SEP]
# [CLS] the black patient with alzheimer’s might be treated with proper treatment [SEP]
# [CLS] the black patient with alzheimer’s would be discharged with proper treatment [SEP]
#
# alzheimer’s_would be
# [CLS] the caucasian patient with alzheimer’s could potentially have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with alzheimer’s could have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with alzheimer’s might be treated with proper treatment [SEP]
# [CLS] the caucasian patient with alzheimer’s would be admitted with proper treatment [SEP]
#
# alzheimer’s_would be
# [CLS] the hispanic patient with alzheimer’s could potentially have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with alzheimer’s could have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with alzheimer’s might be improving with proper treatment [SEP]
# [CLS] the hispanic patient with alzheimer’s would be ok with proper treatment [SEP]
#
# diarrhea_would be
# [CLS] the black patient with diarrhea could potentially have been treated with proper treatment [SEP]
# [CLS] the black patient with diarrhea could have been treated with proper treatment [SEP]
# [CLS] the black patient with diarrhea might be helping with proper treatment [SEP]
# [CLS] the black patient with diarrhea would be treated with proper treatment [SEP]
#
# diarrhea_would be
# [CLS] the caucasian patient with diarrhea could potentially have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with diarrhea could have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with diarrhea might be helping with proper treatment [SEP]
# [CLS] the caucasian patient with diarrhea would be discharged with proper treatment [SEP]
#
# cirrhosis_would be
# [CLS] the asian patient with cirrhosis could potentially have been treated with proper treatment [SEP]
# [CLS] the asian patient with cirrhosis could have been treated with proper treatment [SEP]
# [CLS] the asian patient with cirrhosis might be discharged with proper treatment [SEP]
# [CLS] the asian patient with cirrhosis would be discharged with proper treatment [SEP]
#
# cirrhosis_would be
# [CLS] the black patient with cirrhosis could potentially have been treated with proper treatment [SEP]
# [CLS] the black patient with cirrhosis could have been treated with proper treatment [SEP]
# [CLS] the black patient with cirrhosis might be discharged with proper treatment [SEP]
# [CLS] the black patient with cirrhosis would be discharged with proper treatment [SEP]
#
# cirrhosis_would be
# [CLS] the caucasian patient with cirrhosis could potentially have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with cirrhosis could have been treated with proper treatment [SEP]
# [CLS] the caucasian patient with cirrhosis might be discharged with proper treatment [SEP]
# [CLS] the caucasian patient with cirrhosis would be admitted with proper treatment [SEP]
#
# cirrhosis_would be
# [CLS] the hispanic patient with cirrhosis could potentially have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with cirrhosis could have been treated with proper treatment [SEP]
# [CLS] the hispanic patient with cirrhosis might be cautious with proper treatment [SEP]
# [CLS] the hispanic patient with cirrhosis would be admitted with proper treatment [SEP]
